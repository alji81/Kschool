# %% [markdown]
# ## On this Notebook, I am going to access to Meteorological web from Catalonia's government, in order to download automatically all DATA available from Tarragona (Complex Educatiu) codi_estacio 'XE', Meteo station selected, since the beginning (2009).

# %% [markdown]
# # 1. Download DATA

# %%
#Install Sodapy pack to download data from Pollutant website Catalonia's government
! pip install sodapy
# Out:
# Collecting sodapy
#   Downloading https://files.pythonhosted.org/packages/9e/74/95fb7d45bbe7f1de43caac45d7dd4807ef1e15881564a00eef489a3bb5c6/sodapy-2.1.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from sodapy) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->sodapy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->sodapy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->sodapy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Installing collected packages: sodapy
# Successfully installed sodapy-2.1.0

# %%
#Import libraries required
import os
import pandas as pd
import numpy as np
from sodapy import Socrata
import datetime
import operator

# %%
socrata_domain = "analisi.transparenciacatalunya.cat"
socrata_dataset_identifier = "nzvn-apee"
#socrata_token = os.environ.get("None")

client = Socrata(socrata_domain, None)
print(
    "Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(
        **client.__dict__
    )
)

#metadata = client.get_metadata(socrata_dataset_identifier)
#[x["name"] for x in metadata["columns"]]

results = client.get(socrata_dataset_identifier,
                    limit=4000000,
                    codi_estacio="XE")
    
df = pd.DataFrame.from_dict(results)
df
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Domain: analisi.transparenciacatalunya.cat
# Session: <requests.sessions.Session object at 0x7f42f6b6c690>
# URI Prefix: https://
#                      id codi_estacio  ... codi_base              data_extrem
# 0        XE360502091530           XE  ...        SH                      NaN
# 1        XE340502091530           XE  ...        SH                      NaN
# 2        XE350502091530           XE  ...        SH                      NaN
# 3        XE440502091600           XE  ...        SH  2009-02-05T16:05:00.000
# 4        XE420502091600           XE  ...        SH  2009-02-05T16:28:00.000
# ...                 ...          ...  ...       ...                      ...
# 3447813  XE721407210700           XE  ...        SH  2021-07-14T07:00:00.000
# 3447814  XE721407210730           XE  ...        SH  2021-07-14T07:30:00.000
# 3447815  XE721407210800           XE  ...        SH  2021-07-14T08:00:00.000
# 3447816  XE721407210830           XE  ...        SH  2021-07-14T08:30:00.000
# 3447817  XE721407210900           XE  ...        SH  2021-07-14T09:00:00.000
#
# [3447818 rows x 8 columns]

# %%
#Data object should be modified to datetime, to later on be merged with Pollutant data.
df['data_lectura'] = pd.to_datetime(df['data_lectura'], dayfirst=True)

# %%
#Let's check dataframe size
df.shape
# Out:
# (3447818, 8)

# %%
#Let's check type features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3447818 entries, 0 to 3447817
# Data columns (total 8 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   id             object
#  1   codi_estacio   object
#  2   codi_variable  object
#  3   data_lectura   datetime64[ns]
#  4   valor_lectura  object
#  5   codi_estat     object
#  6   codi_base      object
#  7   data_extrem    object
# dtypes: datetime64[ns](1), object(7)
# memory usage: 210.4+ MB

# %%
#Date is sorted by ascending value
df1 = df.sort_values('data_lectura',ascending=True)
df1
# Out:
#                      id codi_estacio  ... codi_base              data_extrem
# 0        XE360502091530           XE  ...        SH                      NaN
# 1        XE340502091530           XE  ...        SH                      NaN
# 2        XE350502091530           XE  ...        SH                      NaN
# 12       XE500502091600           XE  ...        SH  2009-02-05T16:25:00.000
# 11       XE510502091600           XE  ...        SH                      NaN
# ...                 ...          ...  ...       ...                      ...
# 3447719  XE501407210930           XE  ...        SH  2021-07-14T09:40:00.000
# 3447720  XE511407210930           XE  ...        SH                      NaN
# 3447721  XE721407210930           XE  ...        SH  2021-07-14T09:30:00.000
# 3447713  XE341407210930           XE  ...        SH                      NaN
# 3447717  XE421407210930           XE  ...        SH  2021-07-14T09:51:00.000
#
# [3447818 rows x 8 columns]

# %% [markdown]
# # 2. Select time period to be analyzed

# %%
#Desired period to analyze is 2010-2020. Period decision is made because of many values from 2021 have not been confirmed yet.
#In that case, samples are got by 30 minutes time 
df2 = df1[(df1['data_lectura'] >= '2010-01-01 00:00:01') & (df1['data_lectura'] <= '2020-12-31 23:59:59')]
df2
# Out:
#                      id codi_estacio  ... codi_base              data_extrem
# 218529   XE420101100030           XE  ...        SH  2010-01-01T00:54:00.000
# 218528   XE300101100030           XE  ...        SH                      NaN
# 218527   XE330101100030           XE  ...        SH                      NaN
# 218526   XE340101100030           XE  ...        SH                      NaN
# 218525   XE400101100030           XE  ...        SH  2010-01-01T00:31:00.000
# ...                 ...          ...  ...       ...                      ...
# 3412020  XE403112202330           XE  ...        SH  2020-12-31T23:33:00.000
# 3412021  XE423112202330           XE  ...        SH  2020-12-31T23:52:00.000
# 3412012  XE033112202330           XE  ...        SH  2020-12-31T23:56:00.000
# 3412023  XE503112202330           XE  ...        SH  2020-12-31T23:37:00.000
# 3412022  XE443112202330           XE  ...        SH  2020-12-31T23:36:00.000
#
# [3080024 rows x 8 columns]

# %%
#Let's check new dataframe size
df2.shape
# Out:
# (3080024, 8)

# %%
#Let's reduce dataframe to columns desired: date, feature and value
df3=df2[['data_lectura','codi_variable','valor_lectura']]
df3
# Out:
#                data_lectura codi_variable valor_lectura
# 218529  2010-01-01 00:30:00            42            11
# 218528  2010-01-01 00:30:00            30           7.6
# 218527  2010-01-01 00:30:00            33            42
# 218526  2010-01-01 00:30:00            34           996
# 218525  2010-01-01 00:30:00            40          11.2
# ...                     ...           ...           ...
# 3412020 2020-12-31 23:30:00            40          10.3
# 3412021 2020-12-31 23:30:00            42           9.9
# 3412012 2020-12-31 23:30:00             3            60
# 3412023 2020-12-31 23:30:00            50           5.6
# 3412022 2020-12-31 23:30:00            44            57
#
# [3080024 rows x 3 columns]

# %% [markdown]
# # 3. Structuring Dataset

# %%
#Let's generate a pivot table to allocate meteorological features in columns as features and date samples as rows
table = df3.pivot_table(index='data_lectura', columns='codi_variable', aggfunc=np.sum,)
table
# Out:
#                     valor_lectura                        ...
# codi_variable                   1       2   3   30   31  ...    42  44    50   51 72
# data_lectura                                             ...
# 2010-01-01 00:30:00           997     996  43  7.6  274  ...    11  41  13.8  250  0
# 2010-01-01 01:00:00           997     996  44  8.1  282  ...  10.6  41  15.8  297  0
# 2010-01-01 01:30:00           997     996  48  6.8  276  ...  10.2  44  13.8  295  0
# 2010-01-01 02:00:00           997     997  48  8.4  284  ...   9.7  45  15.1  293  0
# 2010-01-01 02:30:00           998     997  48    8  280  ...   9.5  45  15.6  294  0
# ...                           ...     ...  ..  ...  ...  ...   ...  ..   ...  ... ..
# 2020-12-31 21:30:00        1007.6  1007.4  66  1.2  325  ...   8.1  61   2.1  324  0
# 2020-12-31 22:00:00        1007.5  1007.2  68  0.8  280  ...   7.9  65     2  280  0
# 2020-12-31 22:30:00        1007.3  1006.9  73  0.4   42  ...   7.2  69   1.1  343  0
# 2020-12-31 23:00:00        1006.9  1006.7  74  1.3  267  ...     7  58     5  262  0
# 2020-12-31 23:30:00        1006.8  1006.5  60  2.7  277  ...   9.9  57   5.6  284  0
#
# [192652 rows x 16 columns]

# %%
#Reduce a unique column row
table = pd.DataFrame(table.to_records())
table
# Out:
#               data_lectura  ... ('valor_lectura', '72')
# 0      2010-01-01 00:30:00  ...                       0
# 1      2010-01-01 01:00:00  ...                       0
# 2      2010-01-01 01:30:00  ...                       0
# 3      2010-01-01 02:00:00  ...                       0
# 4      2010-01-01 02:30:00  ...                       0
# ...                    ...  ...                     ...
# 192647 2020-12-31 21:30:00  ...                       0
# 192648 2020-12-31 22:00:00  ...                       0
# 192649 2020-12-31 22:30:00  ...                       0
# 192650 2020-12-31 23:00:00  ...                       0
# 192651 2020-12-31 23:30:00  ...                       0
#
# [192652 rows x 17 columns]

# %%
#Date is sorted by ascending value
table = table.sort_values(['data_lectura'],ascending=True)
table
# Out:
#               data_lectura  ... ('valor_lectura', '72')
# 0      2010-01-01 00:30:00  ...                       0
# 1      2010-01-01 01:00:00  ...                       0
# 2      2010-01-01 01:30:00  ...                       0
# 3      2010-01-01 02:00:00  ...                       0
# 4      2010-01-01 02:30:00  ...                       0
# ...                    ...  ...                     ...
# 192647 2020-12-31 21:30:00  ...                       0
# 192648 2020-12-31 22:00:00  ...                       0
# 192649 2020-12-31 22:30:00  ...                       0
# 192650 2020-12-31 23:00:00  ...                       0
# 192651 2020-12-31 23:30:00  ...                       0
#
# [192652 rows x 17 columns]

# %%
#Show columns
table.columns = ['data_lectura','1','2','3','30','31','32','33','34','35','36','40','42','44','50','51','72']

# %%
#Features values should be transformed to float to be interpreted mathematically
table[['1','2','3','30','31','32','33','34','35','36','40','42','44','50','51','72']] = table[['1','2','3','30','31','32','33','34','35','36','40','42','44','50','51','72']].astype(float)

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192652 entries, 0 to 192651
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   data_lectura  192652 non-null  datetime64[ns]
#  1   1             192480 non-null  float64
#  2   2             192483 non-null  float64
#  3   3             192418 non-null  float64
#  4   30            192633 non-null  float64
#  5   31            192436 non-null  float64
#  6   32            192413 non-null  float64
#  7   33            192487 non-null  float64
#  8   34            192553 non-null  float64
#  9   35            192652 non-null  float64
#  10  36            192536 non-null  float64
#  11  40            192378 non-null  float64
#  12  42            192379 non-null  float64
#  13  44            192416 non-null  float64
#  14  50            192630 non-null  float64
#  15  51            192482 non-null  float64
#  16  72            192648 non-null  float64
# dtypes: datetime64[ns](1), float64(16)
# memory usage: 26.5 MB

# %%
#Table is grouped by daily measures in order to be consistency with Pollutant dataset. It means, daily samples
table1 = table.groupby(table['data_lectura'].dt.date).mean()
table1
# Out:
#                         1            2  ...          51        72
# data_lectura                            ...
# 2010-01-01    1003.531915  1002.680851  ...  271.957447  0.000000
# 2010-01-02    1016.875000  1016.312500  ...  216.187500  0.000000
# 2010-01-03    1016.458333  1016.125000  ...  118.208333  0.000000
# 2010-01-04    1008.625000  1008.354167  ...   82.333333  0.027083
# 2010-01-05    1000.083333   999.833333  ...  174.458333  0.022917
# ...                   ...          ...  ...         ...       ...
# 2020-12-27    1009.404167  1008.766667  ...  240.083333  0.000000
# 2020-12-28     995.566667   994.956250  ...  269.041667  0.000000
# 2020-12-29    1001.879167  1001.518750  ...  270.229167  0.000000
# 2020-12-30    1010.639583  1010.081250  ...  293.333333  0.000000
# 2020-12-31    1011.370833  1011.060417  ...  272.229167  0.000000
#
# [4015 rows x 16 columns]

# %%
table2 = table1.reset_index()
table2
# Out:
#      data_lectura            1            2  ...         50          51        72
# 0      2010-01-01  1003.531915  1002.680851  ...  12.021277  271.957447  0.000000
# 1      2010-01-02  1016.875000  1016.312500  ...   6.714583  216.187500  0.000000
# 2      2010-01-03  1016.458333  1016.125000  ...   2.870833  118.208333  0.000000
# 3      2010-01-04  1008.625000  1008.354167  ...   3.570833   82.333333  0.027083
# 4      2010-01-05  1000.083333   999.833333  ...   3.497917  174.458333  0.022917
# ...           ...          ...          ...  ...        ...         ...       ...
# 4010   2020-12-27  1009.404167  1008.766667  ...   4.272917  240.083333  0.000000
# 4011   2020-12-28   995.566667   994.956250  ...  10.270833  269.041667  0.000000
# 4012   2020-12-29  1001.879167  1001.518750  ...   8.314583  270.229167  0.000000
# 4013   2020-12-30  1010.639583  1010.081250  ...  12.089583  293.333333  0.000000
# 4014   2020-12-31  1011.370833  1011.060417  ...   5.789583  272.229167  0.000000
#
# [4015 rows x 17 columns]

# %% [markdown]
# # 4. Import Features label

# %%
#Features above were downloaded as label numbered, so let's rename the features with Features label accordingly.
socrata_domain = "analisi.transparenciacatalunya.cat"
socrata_dataset_identifier = "4fb2-n3yi"
#socrata_token = os.environ.get("None")

client = Socrata(socrata_domain, None)
print(
    "Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(
        **client.__dict__
    )
)

results = client.get(socrata_dataset_identifier)    
v = pd.DataFrame.from_dict(results)
v.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Domain: analisi.transparenciacatalunya.cat
# Session: <requests.sessions.Session object at 0x7f424d65b110>
# URI Prefix: https://
#   codi_variable                      nom_variable  ... codi_tipus_var decimals
# 0            72    Precipitació màxima en 1 minut  ...            DAT        1
# 1             3           Humitat relativa màxima  ...            DAT        0
# 2            30  Velocitat del vent a 10 m (esc.)  ...            DAT        1
# 3            31      Direcció de vent 10 m (m. 1)  ...            DAT        0
# 4            32                       Temperatura  ...            DAT        1
#
# [5 rows x 6 columns]

# %%
#Dataframe creation
v1 = pd.DataFrame(v.to_records())
v1
# Out:
#     index codi_variable  ... codi_tipus_var decimals
# 0       0            72  ...            DAT        1
# 1       1             3  ...            DAT        0
# 2       2            30  ...            DAT        1
# 3       3            31  ...            DAT        0
# 4       4            32  ...            DAT        1
# 5       5            33  ...            DAT        0
# 6       6            34  ...            DAT        1
# 7       7            35  ...            DAT        1
# 8       8            36  ...            DAT        0
# 9       9            38  ...            DAT        0
# 10     10            40  ...            DAT        1
# 11     11            42  ...            DAT        1
# 12     12            44  ...            DAT        0
# 13     13            46  ...            DAT        1
# 14     14            47  ...            DAT        0
# 15     15            48  ...            DAT        1
# 16     16            49  ...            DAT        0
# 17     17            50  ...            DAT        1
# 18     18            51  ...            DAT        0
# 19     19            53  ...            DAT        1
# 20     20            54  ...            DAT        0
# 21     21            56  ...            DAT        1
# 22     22            57  ...            DAT        0
# 23     23            59  ...            DAT        0
# 24     24             1  ...            DAT        1
# 25     25             2  ...            DAT        1
#
# [26 rows x 7 columns]

# %%
#Let's create a Dictionary to relabel columns
dict = pd.Series(v1.codi_variable.values,index=v1.nom_variable).to_dict()
dict
# Out:
# {'Direcció de la ratxa màxima del vent a 10 m': '51',
#  'Direcció de la ratxa màxima del vent a 2 m': '57',
#  'Direcció de la ratxa màxima del vent a 6 m': '54',
#  'Direcció de vent 10 m (m. 1)': '31',
#  'Direcció del vent a 2 m (m. 1)': '47',
#  'Direcció del vent a 6 m (m. 1)': '49',
#  'Gruix de neu a terra': '38',
#  'Humitat relativa': '33',
#  'Humitat relativa màxima': '3',
#  'Humitat relativa mínima': '44',
#  'Irradiància neta': '59',
#  'Irradiància solar global': '36',
#  'Precipitació': '35',
#  'Precipitació màxima en 1 minut': '72',
#  'Pressió atmosfèrica': '34',
#  'Pressió atmosfèrica màxima': '1',
#  'Pressió atmosfèrica mínima': '2',
#  'Ratxa màxima del vent a 10 m': '50',
#  'Ratxa màxima del vent a 2 m': '56',
#  'Ratxa màxima del vent a 6 m': '53',
#  'Temperatura': '32',
#  'Temperatura màxima': '40',
#  'Temperatura mínima': '42',
#  'Velocitat del vent a 10 m (esc.)': '30',
#  'Velocitat del vent a 2 m (esc.)': '46',
#  'Velocitat del vent a 6 m (esc.)': '48'}

# %%
#Let's sort the dictionary
sorted_dict = sorted(dict.items(), key=operator.itemgetter(1), reverse=False)
sorted_dict
# Out:
# [('Pressió atmosfèrica màxima', '1'),
#  ('Pressió atmosfèrica mínima', '2'),
#  ('Humitat relativa màxima', '3'),
#  ('Velocitat del vent a 10 m (esc.)', '30'),
#  ('Direcció de vent 10 m (m. 1)', '31'),
#  ('Temperatura', '32'),
#  ('Humitat relativa', '33'),
#  ('Pressió atmosfèrica', '34'),
#  ('Precipitació', '35'),
#  ('Irradiància solar global', '36'),
#  ('Gruix de neu a terra', '38'),
#  ('Temperatura màxima', '40'),
#  ('Temperatura mínima', '42'),
#  ('Humitat relativa mínima', '44'),
#  ('Velocitat del vent a 2 m (esc.)', '46'),
#  ('Direcció del vent a 2 m (m. 1)', '47'),
#  ('Velocitat del vent a 6 m (esc.)', '48'),
#  ('Direcció del vent a 6 m (m. 1)', '49'),
#  ('Ratxa màxima del vent a 10 m', '50'),
#  ('Direcció de la ratxa màxima del vent a 10 m', '51'),
#  ('Ratxa màxima del vent a 6 m', '53'),
#  ('Direcció de la ratxa màxima del vent a 6 m', '54'),
#  ('Ratxa màxima del vent a 2 m', '56'),
#  ('Direcció de la ratxa màxima del vent a 2 m', '57'),
#  ('Irradiància neta', '59'),
#  ('Precipitació màxima en 1 minut', '72')]

# %%
#Let's check columns in our tableset
table2.columns
# Out:
# Index(['data_lectura', '1', '2', '3', '30', '31', '32', '33', '34', '35', '36',
#        '40', '42', '44', '50', '51', '72'],
#       dtype='object')

# %%
#Rename columns with feature labels
table2.columns = ['data_lectura','Pressió atmosfèrica màxima',
 'Pressió atmosfèrica mínima',
 'Humitat relativa màxima',
 'Velocitat del vent a 10 m (esc.)',
 'Direcció de vent 10 m (m. 1)',
 'Temperatura',
 'Humitat relativa',
 'Pressió atmosfèrica',
 'Precipitació',
 'Irradiància solar global',
 'Temperatura màxima',
 'Temperatura mínima',
 'Humitat relativa mínima',
 'Ratxa màxima del vent a 10 m',
 'Direcció de la ratxa màxima del vent a 10 m',
 'Precipitació màxima en 1 minut']

# %%
#Check dataframe results
table2
# Out:
#      data_lectura  ...  Precipitació màxima en 1 minut
# 0      2010-01-01  ...                        0.000000
# 1      2010-01-02  ...                        0.000000
# 2      2010-01-03  ...                        0.000000
# 3      2010-01-04  ...                        0.027083
# 4      2010-01-05  ...                        0.022917
# ...           ...  ...                             ...
# 4010   2020-12-27  ...                        0.000000
# 4011   2020-12-28  ...                        0.000000
# 4012   2020-12-29  ...                        0.000000
# 4013   2020-12-30  ...                        0.000000
# 4014   2020-12-31  ...                        0.000000
#
# [4015 rows x 17 columns]

# %%
#Confirm features type
table2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4015 entries, 0 to 4014
# Data columns (total 17 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   data_lectura                                 4015 non-null   object
#  1   Pressió atmosfèrica màxima                   4014 non-null   float64
#  2   Pressió atmosfèrica mínima                   4014 non-null   float64
#  3   Humitat relativa màxima                      4014 non-null   float64
#  4   Velocitat del vent a 10 m (esc.)             4015 non-null   float64
#  5   Direcció de vent 10 m (m. 1)                 4014 non-null   float64
#  6   Temperatura                                  4013 non-null   float64
#  7   Humitat relativa                             4014 non-null   float64
#  8   Pressió atmosfèrica                          4014 non-null   float64
#  9   Precipitació                                 4015 non-null   float64
#  10  Irradiància solar global                     4014 non-null   float64
#  11  Temperatura màxima                           4013 non-null   float64
#  12  Temperatura mínima                           4013 non-null   float64
#  13  Humitat relativa mínima                      4014 non-null   float64
#  14  Ratxa màxima del vent a 10 m                 4015 non-null   float64
#  15  Direcció de la ratxa màxima del vent a 10 m  4014 non-null   float64
#  16  Precipitació màxima en 1 minut               4015 non-null   float64
# dtypes: float64(16), object(1)
# memory usage: 533.4+ KB

# %% [markdown]
# # 5. Export Dataset

# %%
#Finally, Meteorological dataset is exported to csv to be merged with Polluntants
table2.to_csv(r'Data_sets/Meteo_ready.csv')
