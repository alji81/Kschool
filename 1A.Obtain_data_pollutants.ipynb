# %% [markdown]
# ## On this Notebook, I am going to access to Pollutant web from Catalonia's government, in order to download automatically all DATA available from Tarragona (Bonavista), Pollutant station selected, since the beginning (1991).

# %% [markdown]
# # 1. Download DATA

# %%
#Install Sodapy pack to download data from Pollutant website Catalonia's government
! pip install sodapy
# Out:
# Requirement already satisfied: sodapy in /home/dsc/anaconda3/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied: requests>=2.20.0 in /home/dsc/anaconda3/lib/python3.7/site-packages (from sodapy) (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/dsc/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dsc/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /home/dsc/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (2.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/dsc/anaconda3/lib/python3.7/site-packages (from requests>=2.20.0->sodapy) (3.0.4)

# %%
#Import libraries required
import os
import pandas as pd
import numpy as np
from sodapy import Socrata
import datetime

# %%
#Download data info from web. It is not needed token because we will download data once.
socrata_domain = "analisi.transparenciacatalunya.cat"
socrata_dataset_identifier = "tasf-thgu"
#socrata_token = os.environ.get("None") --> not needed, but just in case, here we have the sentence to include it.

client = Socrata(socrata_domain, None)
print(
    "Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(
        **client.__dict__
    )
)

metadata = client.get_metadata(socrata_dataset_identifier)
[x["name"] for x in metadata["columns"]]

results = client.get(socrata_dataset_identifier,
                    limit=100000, 
                    nom_estacio="Tarragona (Bonavista)")    
    
df = pd.DataFrame.from_dict(results)
df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Domain: analisi.transparenciacatalunya.cat
# Session: <requests.sessions.Session object at 0x7f318f164c50>
# URI Prefix: https://
#    codi_eoi            nom_estacio                     data magnitud  \
# 0  43148003  Tarragona (Bonavista)  2014-07-28T00:00:00.000       11
# 1  43148003  Tarragona (Bonavista)  2014-05-04T00:00:00.000        7
# 2  43148003  Tarragona (Bonavista)  2014-04-15T00:00:00.000       11
# 3  43148003  Tarragona (Bonavista)  2014-10-09T00:00:00.000       11
# 4  43148003  Tarragona (Bonavista)  2014-05-15T00:00:00.000       12
#
#   contaminant unitats tipus_estacio area_urbana codi_ine   municipi  ... h19  \
# 0         PM1   µg/m3    industrial  peri-urban    43148  Tarragona  ...  10
# 1          NO   µg/m3    industrial  peri-urban    43148  Tarragona  ...   3
# 2         PM1   µg/m3    industrial  peri-urban    43148  Tarragona  ...  10
# 3         PM1   µg/m3    industrial  peri-urban    43148  Tarragona  ...  19
# 4         NOX   µg/m3    industrial  peri-urban    43148  Tarragona  ...   6
#
#   h20 h21 h22 h23 h24 altitud   latitud  longitud  \
# 0   9   7   8  10  11      39  41.11591  1.191999
# 1   2   1   1   1   3      39  41.11591  1.191999
# 2  14  14  17  20  31      39  41.11591  1.191999
# 3  15  18  16  22  26      39  41.11591  1.191999
# 4   3   3  13   6   5      39  41.11591  1.191999
#
#                                      geocoded_column
# 0  {'type': 'Point', 'coordinates': [1.191999, 41...
# 1  {'type': 'Point', 'coordinates': [1.191999, 41...
# 2  {'type': 'Point', 'coordinates': [1.191999, 41...
# 3  {'type': 'Point', 'coordinates': [1.191999, 41...
# 4  {'type': 'Point', 'coordinates': [1.191999, 41...
#
# [5 rows x 40 columns]

# %%
#Data object should be modified to datetime, to later on be merged with Meteorological data.
df['data'] = pd.to_datetime(df['data'])

# %%
#Let's check dataframe size
df.shape
# Out:
# (67847, 40)

# %%
#Let's check type features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67847 entries, 0 to 67846
# Data columns (total 40 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   codi_eoi         67847 non-null  object
#  1   nom_estacio      67847 non-null  object
#  2   data             67847 non-null  datetime64[ns]
#  3   magnitud         67847 non-null  object
#  4   contaminant      67847 non-null  object
#  5   unitats          67847 non-null  object
#  6   tipus_estacio    67847 non-null  object
#  7   area_urbana      67847 non-null  object
#  8   codi_ine         67847 non-null  object
#  9   municipi         67847 non-null  object
#  10  codi_comarca     67847 non-null  object
#  11  nom_comarca      67847 non-null  object
#  12  h01              65670 non-null  object
#  13  h02              65495 non-null  object
#  14  h03              66307 non-null  object
#  15  h04              66372 non-null  object
#  16  h05              66356 non-null  object
#  17  h06              66323 non-null  object
#  18  h07              66331 non-null  object
#  19  h08              66336 non-null  object
#  20  h09              66210 non-null  object
#  21  h10              66032 non-null  object
#  22  h11              65795 non-null  object
#  23  h12              65372 non-null  object
#  24  h13              64861 non-null  object
#  25  h14              65023 non-null  object
#  26  h15              65776 non-null  object
#  27  h16              66154 non-null  object
#  28  h17              65984 non-null  object
#  29  h18              66209 non-null  object
#  30  h19              66322 non-null  object
#  31  h20              66314 non-null  object
#  32  h21              66261 non-null  object
#  33  h22              66138 non-null  object
#  34  h23              65953 non-null  object
#  35  h24              65263 non-null  object
#  36  altitud          67847 non-null  object
#  37  latitud          67847 non-null  object
#  38  longitud         67847 non-null  object
#  39  geocoded_column  67847 non-null  object
# dtypes: datetime64[ns](1), object(39)
# memory usage: 20.7+ MB

# %%
#Date is sorted by ascending value
df1 = df.sort_values('data',ascending=True)
df1
# Out:
#        codi_eoi            nom_estacio       data magnitud contaminant  \
# 23925  43148003  Tarragona (Bonavista) 1991-04-01        6          CO
# 24584  43148003  Tarragona (Bonavista) 1991-04-01        7          NO
# 24780  43148003  Tarragona (Bonavista) 1991-04-01       44        HCNM
# 24227  43148003  Tarragona (Bonavista) 1991-04-01       65         H2S
# 26746  43148003  Tarragona (Bonavista) 1991-04-01        8         NO2
# ...         ...                    ...        ...      ...         ...
# 67268  43148003  Tarragona (Bonavista) 2021-07-19       11         PM1
# 67269  43148003  Tarragona (Bonavista) 2021-07-19        8         NO2
# 67270  43148003  Tarragona (Bonavista) 2021-07-19        9       PM2.5
# 67277  43148003  Tarragona (Bonavista) 2021-07-19       12         NOX
# 67217  43148003  Tarragona (Bonavista) 2021-07-19        1         SO2
#
#       unitats tipus_estacio area_urbana codi_ine   municipi  ...  h19  h20  \
# 23925   mg/m3    industrial  peri-urban    43148  Tarragona  ...  0.4  0.4
# 24584   µg/m3    industrial  peri-urban    43148  Tarragona  ...    4    3
# 24780     ppm    industrial  peri-urban    43148  Tarragona  ...    0    0
# 24227   µg/m3    industrial  peri-urban    43148  Tarragona  ...  0.7    1
# 26746   µg/m3    industrial  peri-urban    43148  Tarragona  ...   41   51
# ...       ...           ...         ...      ...        ...  ...  ...  ...
# 67268   µg/m3    industrial    suburban    43148  Tarragona  ...  NaN  NaN
# 67269   µg/m3    industrial    suburban    43148  Tarragona  ...  NaN  NaN
# 67270   µg/m3    industrial    suburban    43148  Tarragona  ...  NaN  NaN
# 67277   µg/m3    industrial    suburban    43148  Tarragona  ...  NaN  NaN
# 67217   µg/m3    industrial    suburban    43148  Tarragona  ...  NaN  NaN
#
#        h21  h22  h23  h24 altitud   latitud   longitud  \
# 23925  0.5  0.9  1.1  0.8      39  41.11591   1.191999
# 24584    3    5    9    4      39  41.11591   1.191999
# 24780    0    0    0    0      39  41.11591   1.191999
# 24227  1.3  1.3  1.8  1.3      39  41.11591   1.191999
# 26746   66  106  135  109      39  41.11591   1.191999
# ...    ...  ...  ...  ...     ...       ...        ...
# 67268  NaN  NaN  NaN  NaN      39  41.11591  1.1919986
# 67269  NaN  NaN  NaN  NaN      39  41.11591  1.1919986
# 67270  NaN  NaN  NaN  NaN      39  41.11591  1.1919986
# 67277  NaN  NaN  NaN  NaN      39  41.11591  1.1919986
# 67217  NaN  NaN  NaN  NaN      39  41.11591  1.1919986
#
#                                          geocoded_column
# 23925  {'type': 'Point', 'coordinates': [1.191999, 41...
# 24584  {'type': 'Point', 'coordinates': [1.191999, 41...
# 24780  {'type': 'Point', 'coordinates': [1.191999, 41...
# 24227  {'type': 'Point', 'coordinates': [1.191999, 41...
# 26746  {'type': 'Point', 'coordinates': [1.191999, 41...
# ...                                                  ...
# 67268  {'type': 'Point', 'coordinates': [1.1919986, 4...
# 67269  {'type': 'Point', 'coordinates': [1.1919986, 4...
# 67270  {'type': 'Point', 'coordinates': [1.1919986, 4...
# 67277  {'type': 'Point', 'coordinates': [1.1919986, 4...
# 67217  {'type': 'Point', 'coordinates': [1.1919986, 4...
#
# [67847 rows x 40 columns]

# %% [markdown]
# # 2. Select time period to be analyzed

# %%
#Desired period to analyze is 2010-2020. Period decision is made because of many values from 2021 have not been confirmed yet.
df2 = df1[(df1['data'] >= '2010-01-01') & (df1['data'] <= '2020-12-31')]
df2
# Out:
#        codi_eoi            nom_estacio       data magnitud contaminant  \
# 65531  43148003  Tarragona (Bonavista) 2010-01-01        1         SO2
# 64476  43148003  Tarragona (Bonavista) 2010-01-01       65         H2S
# 65109  43148003  Tarragona (Bonavista) 2010-01-01        8         NO2
# 64939  43148003  Tarragona (Bonavista) 2010-01-01        7          NO
# 64100  43148003  Tarragona (Bonavista) 2010-01-01        6          CO
# ...         ...                    ...        ...      ...         ...
# 66931  43148003  Tarragona (Bonavista) 2020-12-31       10        PM10
# 66933  43148003  Tarragona (Bonavista) 2020-12-31       12         NOX
# 66937  43148003  Tarragona (Bonavista) 2020-12-31        8         NO2
# 66938  43148003  Tarragona (Bonavista) 2020-12-31        9       PM2.5
# 66936  43148003  Tarragona (Bonavista) 2020-12-31        7          NO
#
#       unitats tipus_estacio area_urbana codi_ine   municipi  ...  h19  h20  \
# 65531   µg/m3    industrial  peri-urban    43148  Tarragona  ...    1    1
# 64476   µg/m3    industrial  peri-urban    43148  Tarragona  ...    1    1
# 65109   µg/m3    industrial  peri-urban    43148  Tarragona  ...    3    7
# 64939   µg/m3    industrial  peri-urban    43148  Tarragona  ...    1    1
# 64100   mg/m3    industrial  peri-urban    43148  Tarragona  ...  0.2  0.2
# ...       ...           ...         ...      ...        ...  ...  ...  ...
# 66931   µg/m3    industrial    suburban    43148  Tarragona  ...   22   22
# 66933   µg/m3    industrial    suburban    43148  Tarragona  ...   19   27
# 66937   µg/m3    industrial    suburban    43148  Tarragona  ...   18   25
# 66938   µg/m3    industrial    suburban    43148  Tarragona  ...    4   19
# 66936   µg/m3    industrial    suburban    43148  Tarragona  ...    1    1
#
#        h21  h22  h23  h24 altitud   latitud   longitud  \
# 65531    1    1    1    1      39  41.11591   1.191999
# 64476    1  1.1  1.1  1.3      39  41.11591   1.191999
# 65109    3    3    7    5      39  41.11591   1.191999
# 64939    1    1    1    1      39  41.11591   1.191999
# 64100  0.2  0.2  0.2  0.2      39  41.11591   1.191999
# ...    ...  ...  ...  ...     ...       ...        ...
# 66931   23   27   25   23      39  41.11591  1.1919986
# 66933   37   51   35   22      39  41.11591  1.1919986
# 66937   32   40   32   20      39  41.11591  1.1919986
# 66938   17   20   22   20      39  41.11591  1.1919986
# 66936    4    7    2    1      39  41.11591  1.1919986
#
#                                          geocoded_column
# 65531  {'type': 'Point', 'coordinates': [1.191999, 41...
# 64476  {'type': 'Point', 'coordinates': [1.191999, 41...
# 65109  {'type': 'Point', 'coordinates': [1.191999, 41...
# 64939  {'type': 'Point', 'coordinates': [1.191999, 41...
# 64100  {'type': 'Point', 'coordinates': [1.191999, 41...
# ...                                                  ...
# 66931  {'type': 'Point', 'coordinates': [1.1919986, 4...
# 66933  {'type': 'Point', 'coordinates': [1.1919986, 4...
# 66937  {'type': 'Point', 'coordinates': [1.1919986, 4...
# 66938  {'type': 'Point', 'coordinates': [1.1919986, 4...
# 66936  {'type': 'Point', 'coordinates': [1.1919986, 4...
#
# [28283 rows x 40 columns]

# %%
#Let's check new dataframe size
df2.shape
# Out:
# (28283, 40)

# %%
#Show columns
df2.columns
# Out:
# Index(['codi_eoi', 'nom_estacio', 'data', 'magnitud', 'contaminant', 'unitats',
#        'tipus_estacio', 'area_urbana', 'codi_ine', 'municipi', 'codi_comarca',
#        'nom_comarca', 'h01', 'h02', 'h03', 'h04', 'h05', 'h06', 'h07', 'h08',
#        'h09', 'h10', 'h11', 'h12', 'h13', 'h14', 'h15', 'h16', 'h17', 'h18',
#        'h19', 'h20', 'h21', 'h22', 'h23', 'h24', 'altitud', 'latitud',
#        'longitud', 'geocoded_column'],
#       dtype='object')

# %%
#Features values should be transformed to float to be interpreted mathematically
df2[['h01', 'h02', 'h03', 'h04', 'h05', 'h06', 'h07', 'h08',
       'h09', 'h10', 'h11', 'h12', 'h13', 'h14', 'h15', 'h16', 'h17', 'h18',
       'h19', 'h20', 'h21', 'h22', 'h23', 'h24']] = df2[['h01', 'h02', 'h03', 'h04', 'h05', 'h06', 'h07', 'h08',
       'h09', 'h10', 'h11', 'h12', 'h13', 'h14', 'h15', 'h16', 'h17', 'h18',
       'h19', 'h20', 'h21', 'h22', 'h23', 'h24']].astype(float)
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
#Let's confirm type features modified
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28283 entries, 65531 to 66936
# Data columns (total 40 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   codi_eoi         28283 non-null  object
#  1   nom_estacio      28283 non-null  object
#  2   data             28283 non-null  datetime64[ns]
#  3   magnitud         28283 non-null  object
#  4   contaminant      28283 non-null  object
#  5   unitats          28283 non-null  object
#  6   tipus_estacio    28283 non-null  object
#  7   area_urbana      28283 non-null  object
#  8   codi_ine         28283 non-null  object
#  9   municipi         28283 non-null  object
#  10  codi_comarca     28283 non-null  object
#  11  nom_comarca      28283 non-null  object
#  12  h01              27277 non-null  float64
#  13  h02              27121 non-null  float64
#  14  h03              27818 non-null  float64
#  15  h04              27870 non-null  float64
#  16  h05              27870 non-null  float64
#  17  h06              27858 non-null  float64
#  18  h07              27847 non-null  float64
#  19  h08              27849 non-null  float64
#  20  h09              27802 non-null  float64
#  21  h10              27717 non-null  float64
#  22  h11              27667 non-null  float64
#  23  h12              27539 non-null  float64
#  24  h13              27316 non-null  float64
#  25  h14              27240 non-null  float64
#  26  h15              27452 non-null  float64
#  27  h16              27746 non-null  float64
#  28  h17              27880 non-null  float64
#  29  h18              27893 non-null  float64
#  30  h19              27837 non-null  float64
#  31  h20              27836 non-null  float64
#  32  h21              27837 non-null  float64
#  33  h22              27785 non-null  float64
#  34  h23              27718 non-null  float64
#  35  h24              27397 non-null  float64
#  36  altitud          28283 non-null  object
#  37  latitud          28283 non-null  object
#  38  longitud         28283 non-null  object
#  39  geocoded_column  28283 non-null  object
# dtypes: datetime64[ns](1), float64(24), object(15)
# memory usage: 8.8+ MB

# %%
#Let's create a column at the end of dataframe with average daily value and maximum value for any feature
ave = df2.loc[: , "h01":"h24"]
df2['promedio'] = ave.mean(axis=1)
maxi = df2.loc[: , "h01":"h24"]
df2['maximo'] = maxi.max(axis=1)
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/dsc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#Let's confirm dataframe
df2.head()
# Out:
#        codi_eoi            nom_estacio       data magnitud contaminant  \
# 65531  43148003  Tarragona (Bonavista) 2010-01-01        1         SO2
# 64476  43148003  Tarragona (Bonavista) 2010-01-01       65         H2S
# 65109  43148003  Tarragona (Bonavista) 2010-01-01        8         NO2
# 64939  43148003  Tarragona (Bonavista) 2010-01-01        7          NO
# 64100  43148003  Tarragona (Bonavista) 2010-01-01        6          CO
#
#       unitats tipus_estacio area_urbana codi_ine   municipi  ...  h21  h22  \
# 65531   µg/m3    industrial  peri-urban    43148  Tarragona  ...  1.0  1.0
# 64476   µg/m3    industrial  peri-urban    43148  Tarragona  ...  1.0  1.1
# 65109   µg/m3    industrial  peri-urban    43148  Tarragona  ...  3.0  3.0
# 64939   µg/m3    industrial  peri-urban    43148  Tarragona  ...  1.0  1.0
# 64100   mg/m3    industrial  peri-urban    43148  Tarragona  ...  0.2  0.2
#
#        h23  h24  altitud   latitud  longitud  \
# 65531  1.0  1.0       39  41.11591  1.191999
# 64476  1.1  1.3       39  41.11591  1.191999
# 65109  7.0  5.0       39  41.11591  1.191999
# 64939  1.0  1.0       39  41.11591  1.191999
# 64100  0.2  0.2       39  41.11591  1.191999
#
#                                          geocoded_column  promedio  maximo
# 65531  {'type': 'Point', 'coordinates': [1.191999, 41...  1.000000     1.0
# 64476  {'type': 'Point', 'coordinates': [1.191999, 41...  1.108333     1.4
# 65109  {'type': 'Point', 'coordinates': [1.191999, 41...  2.625000     7.0
# 64939  {'type': 'Point', 'coordinates': [1.191999, 41...  1.000000     1.0
# 64100  {'type': 'Point', 'coordinates': [1.191999, 41...  0.200000     0.2
#
# [5 rows x 42 columns]

# %%
#Let's reduce dataframe to columns desired: date, pollutant, average and maximum value
df3=df2[['data','contaminant','promedio','maximo']]
df3
# Out:
#             data contaminant   promedio  maximo
# 65531 2010-01-01         SO2   1.000000     1.0
# 64476 2010-01-01         H2S   1.108333     1.4
# 65109 2010-01-01         NO2   2.625000     7.0
# 64939 2010-01-01          NO   1.000000     1.0
# 64100 2010-01-01          CO   0.200000     0.2
# ...          ...         ...        ...     ...
# 66931 2020-12-31        PM10   8.916667    27.0
# 66933 2020-12-31         NOX  12.583333    51.0
# 66937 2020-12-31         NO2  10.791667    40.0
# 66938 2020-12-31       PM2.5   6.708333    22.0
# 66936 2020-12-31          NO   1.500000     7.0
#
# [28283 rows x 4 columns]

# %% [markdown]
# # 3. Structuring Dataset

# %%
#Let's generate a pivot table to allocate pollutant in columns as features and date samples as rows
table = df3.pivot_table(index='data', columns='contaminant', aggfunc=np.sum)
table
# Out:
#             maximo                                                promedio  \
# contaminant     CO  H2S    NO   NO2   NOX   PM1  PM10 PM2.5  SO2        CO
# data
# 2010-01-01     0.2  1.4   1.0   7.0   NaN   NaN   NaN   NaN  1.0  0.200000
# 2010-01-02     0.2  1.8  13.0  44.0   NaN   NaN   NaN   NaN  1.0  0.200000
# 2010-01-03     0.3  1.6  17.0  48.0   NaN   NaN   NaN   NaN  7.0  0.204167
# 2010-01-04     0.2  2.0  26.0  42.0   NaN   NaN   NaN   NaN  4.0  0.200000
# 2010-01-05     0.4  1.4  23.0  44.0   NaN   NaN   NaN   NaN  2.0  0.220833
# ...            ...  ...   ...   ...   ...   ...   ...   ...  ...       ...
# 2020-12-27     NaN  3.1  13.0  44.0  63.0  23.0  28.0  24.0  5.0       NaN
# 2020-12-28     NaN  1.6   6.0  27.0  37.0   4.0  26.0   6.0  9.0       NaN
# 2020-12-29     NaN  1.5   5.0  15.0  16.0   8.0  14.0   9.0  4.0       NaN
# 2020-12-30     NaN  1.3   3.0  20.0  25.0   2.0  42.0   5.0  1.0       NaN
# 2020-12-31     NaN  1.5   7.0  40.0  51.0  21.0  27.0  22.0  1.0       NaN
#
#                                                                             \
# contaminant       H2S        NO        NO2        NOX       PM1       PM10
# data
# 2010-01-01   1.108333  1.000000   2.625000        NaN       NaN        NaN
# 2010-01-02   1.137500  2.250000  12.916667        NaN       NaN        NaN
# 2010-01-03   1.158333  3.625000  22.166667        NaN       NaN        NaN
# 2010-01-04   1.382609  8.217391  28.304348        NaN       NaN        NaN
# 2010-01-05   1.037500  5.750000  24.958333        NaN       NaN        NaN
# ...               ...       ...        ...        ...       ...        ...
# 2020-12-27   1.408333  2.833333  13.625000  17.416667  8.291667  10.458333
# 2020-12-28   1.208333  1.541667   7.833333   9.666667  2.083333   7.541667
# 2020-12-29   1.150000  1.250000   6.791667   8.166667  2.458333   4.708333
# 2020-12-30   1.120833  1.208333   5.458333   6.916667  1.416667   7.500000
# 2020-12-31   1.175000  1.500000  10.791667  12.583333  5.958333   8.916667
#
#
# contaminant     PM2.5       SO2
# data
# 2010-01-01        NaN  1.000000
# 2010-01-02        NaN  1.000000
# 2010-01-03        NaN  1.875000
# 2010-01-04        NaN  1.652174
# 2010-01-05        NaN  1.083333
# ...               ...       ...
# 2020-12-27   8.916667  1.500000
# 2020-12-28   3.083333  5.416667
# 2020-12-29   3.208333  2.333333
# 2020-12-30   2.250000  1.000000
# 2020-12-31   6.708333  1.000000
#
# [3992 rows x 18 columns]

# %%
#Reduce a unique column row
table = pd.DataFrame(table.to_records())
table
# Out:
#            data  ('maximo', 'CO')  ('maximo', 'H2S')  ('maximo', 'NO')  \
# 0    2010-01-01               0.2                1.4               1.0
# 1    2010-01-02               0.2                1.8              13.0
# 2    2010-01-03               0.3                1.6              17.0
# 3    2010-01-04               0.2                2.0              26.0
# 4    2010-01-05               0.4                1.4              23.0
# ...         ...               ...                ...               ...
# 3987 2020-12-27               NaN                3.1              13.0
# 3988 2020-12-28               NaN                1.6               6.0
# 3989 2020-12-29               NaN                1.5               5.0
# 3990 2020-12-30               NaN                1.3               3.0
# 3991 2020-12-31               NaN                1.5               7.0
#
#       ('maximo', 'NO2')  ('maximo', 'NOX')  ('maximo', 'PM1')  \
# 0                   7.0                NaN                NaN
# 1                  44.0                NaN                NaN
# 2                  48.0                NaN                NaN
# 3                  42.0                NaN                NaN
# 4                  44.0                NaN                NaN
# ...                 ...                ...                ...
# 3987               44.0               63.0               23.0
# 3988               27.0               37.0                4.0
# 3989               15.0               16.0                8.0
# 3990               20.0               25.0                2.0
# 3991               40.0               51.0               21.0
#
#       ('maximo', 'PM10')  ('maximo', 'PM2.5')  ('maximo', 'SO2')  \
# 0                    NaN                  NaN                1.0
# 1                    NaN                  NaN                1.0
# 2                    NaN                  NaN                7.0
# 3                    NaN                  NaN                4.0
# 4                    NaN                  NaN                2.0
# ...                  ...                  ...                ...
# 3987                28.0                 24.0                5.0
# 3988                26.0                  6.0                9.0
# 3989                14.0                  9.0                4.0
# 3990                42.0                  5.0                1.0
# 3991                27.0                 22.0                1.0
#
#       ('promedio', 'CO')  ('promedio', 'H2S')  ('promedio', 'NO')  \
# 0               0.200000             1.108333            1.000000
# 1               0.200000             1.137500            2.250000
# 2               0.204167             1.158333            3.625000
# 3               0.200000             1.382609            8.217391
# 4               0.220833             1.037500            5.750000
# ...                  ...                  ...                 ...
# 3987                 NaN             1.408333            2.833333
# 3988                 NaN             1.208333            1.541667
# 3989                 NaN             1.150000            1.250000
# 3990                 NaN             1.120833            1.208333
# 3991                 NaN             1.175000            1.500000
#
#       ('promedio', 'NO2')  ('promedio', 'NOX')  ('promedio', 'PM1')  \
# 0                2.625000                  NaN                  NaN
# 1               12.916667                  NaN                  NaN
# 2               22.166667                  NaN                  NaN
# 3               28.304348                  NaN                  NaN
# 4               24.958333                  NaN                  NaN
# ...                   ...                  ...                  ...
# 3987            13.625000            17.416667             8.291667
# 3988             7.833333             9.666667             2.083333
# 3989             6.791667             8.166667             2.458333
# 3990             5.458333             6.916667             1.416667
# 3991            10.791667            12.583333             5.958333
#
#       ('promedio', 'PM10')  ('promedio', 'PM2.5')  ('promedio', 'SO2')
# 0                      NaN                    NaN             1.000000
# 1                      NaN                    NaN             1.000000
# 2                      NaN                    NaN             1.875000
# 3                      NaN                    NaN             1.652174
# 4                      NaN                    NaN             1.083333
# ...                    ...                    ...                  ...
# 3987             10.458333               8.916667             1.500000
# 3988              7.541667               3.083333             5.416667
# 3989              4.708333               3.208333             2.333333
# 3990              7.500000               2.250000             1.000000
# 3991              8.916667               6.708333             1.000000
#
# [3992 rows x 19 columns]

# %%
#Columns are going to be renamed
table.columns
# Out:
# Index(['data', '('maximo', 'CO')', '('maximo', 'H2S')', '('maximo', 'NO')',
#        '('maximo', 'NO2')', '('maximo', 'NOX')', '('maximo', 'PM1')',
#        '('maximo', 'PM10')', '('maximo', 'PM2.5')', '('maximo', 'SO2')',
#        '('promedio', 'CO')', '('promedio', 'H2S')', '('promedio', 'NO')',
#        '('promedio', 'NO2')', '('promedio', 'NOX')', '('promedio', 'PM1')',
#        '('promedio', 'PM10')', '('promedio', 'PM2.5')', '('promedio', 'SO2')'],
#       dtype='object')

# %%
#Let's rename columns
table.columns = ['data','CO max','H2S max','NO max','NO2 max','NOx max','PM1 max','PM10 max','PM2.5 max','SO2 max','CO','H2S','NO','NO2','NOx','PM1','PM10','PM2.5','SO2']
table
# Out:
#            data  CO max  H2S max  NO max  NO2 max  NOx max  PM1 max  PM10 max  \
# 0    2010-01-01     0.2      1.4     1.0      7.0      NaN      NaN       NaN
# 1    2010-01-02     0.2      1.8    13.0     44.0      NaN      NaN       NaN
# 2    2010-01-03     0.3      1.6    17.0     48.0      NaN      NaN       NaN
# 3    2010-01-04     0.2      2.0    26.0     42.0      NaN      NaN       NaN
# 4    2010-01-05     0.4      1.4    23.0     44.0      NaN      NaN       NaN
# ...         ...     ...      ...     ...      ...      ...      ...       ...
# 3987 2020-12-27     NaN      3.1    13.0     44.0     63.0     23.0      28.0
# 3988 2020-12-28     NaN      1.6     6.0     27.0     37.0      4.0      26.0
# 3989 2020-12-29     NaN      1.5     5.0     15.0     16.0      8.0      14.0
# 3990 2020-12-30     NaN      1.3     3.0     20.0     25.0      2.0      42.0
# 3991 2020-12-31     NaN      1.5     7.0     40.0     51.0     21.0      27.0
#
#       PM2.5 max  SO2 max        CO       H2S        NO        NO2        NOx  \
# 0           NaN      1.0  0.200000  1.108333  1.000000   2.625000        NaN
# 1           NaN      1.0  0.200000  1.137500  2.250000  12.916667        NaN
# 2           NaN      7.0  0.204167  1.158333  3.625000  22.166667        NaN
# 3           NaN      4.0  0.200000  1.382609  8.217391  28.304348        NaN
# 4           NaN      2.0  0.220833  1.037500  5.750000  24.958333        NaN
# ...         ...      ...       ...       ...       ...        ...        ...
# 3987       24.0      5.0       NaN  1.408333  2.833333  13.625000  17.416667
# 3988        6.0      9.0       NaN  1.208333  1.541667   7.833333   9.666667
# 3989        9.0      4.0       NaN  1.150000  1.250000   6.791667   8.166667
# 3990        5.0      1.0       NaN  1.120833  1.208333   5.458333   6.916667
# 3991       22.0      1.0       NaN  1.175000  1.500000  10.791667  12.583333
#
#            PM1       PM10     PM2.5       SO2
# 0          NaN        NaN       NaN  1.000000
# 1          NaN        NaN       NaN  1.000000
# 2          NaN        NaN       NaN  1.875000
# 3          NaN        NaN       NaN  1.652174
# 4          NaN        NaN       NaN  1.083333
# ...        ...        ...       ...       ...
# 3987  8.291667  10.458333  8.916667  1.500000
# 3988  2.083333   7.541667  3.083333  5.416667
# 3989  2.458333   4.708333  3.208333  2.333333
# 3990  1.416667   7.500000  2.250000  1.000000
# 3991  5.958333   8.916667  6.708333  1.000000
#
# [3992 rows x 19 columns]

# %%
#Summary of table got
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3992 entries, 0 to 3991
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   data       3992 non-null   datetime64[ns]
#  1   CO max     343 non-null    float64
#  2   H2S max    3961 non-null   float64
#  3   NO max     3952 non-null   float64
#  4   NO2 max    3952 non-null   float64
#  5   NOx max    3323 non-null   float64
#  6   PM1 max    2638 non-null   float64
#  7   PM10 max   3073 non-null   float64
#  8   PM2.5 max  3066 non-null   float64
#  9   SO2 max    3975 non-null   float64
#  10  CO         343 non-null    float64
#  11  H2S        3961 non-null   float64
#  12  NO         3952 non-null   float64
#  13  NO2        3952 non-null   float64
#  14  NOx        3323 non-null   float64
#  15  PM1        2638 non-null   float64
#  16  PM10       3073 non-null   float64
#  17  PM2.5      3066 non-null   float64
#  18  SO2        3975 non-null   float64
# dtypes: datetime64[ns](1), float64(18)
# memory usage: 592.7 KB

# %% [markdown]
# # 4. Export Dataset

# %%
#Finally, Pollutant dataset is exported to csv to be merged with Meteorological dataset
table.to_csv(r'Data_sets/Pollutant_ready.csv')
