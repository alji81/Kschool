# %% [markdown]
# ## In this Notebook, I will define a target feature, and based on that, I will pre-process, analyse and select data/features in order to be modelled under any Supervised Machine Learning model. Once the model was selected and tuned, it will be saved ready to be used in the FrontEnd app.

# %% [markdown]
# # 1. Import DATA set

# %%
#Import libraries to manage Dataset. The rest of libraries needed will be imported later on once requiered.
import numpy as np
import pandas as pd

# %%
#Peek our data
df = pd.read_csv('Data_sets/Pollutant_Meteo_merged_ready.csv',index_col=0)
pd.options.display.max_columns = None
df
# Out:
#             data  CO max  H2S max  NO max  NO2 max  NOx max  PM1 max  \
# 0     2010-01-01     0.2      1.4     1.0      7.0      NaN      NaN
# 1     2010-01-02     0.2      1.8    13.0     44.0      NaN      NaN
# 2     2010-01-03     0.3      1.6    17.0     48.0      NaN      NaN
# 3     2010-01-04     0.2      2.0    26.0     42.0      NaN      NaN
# 4     2010-01-05     0.4      1.4    23.0     44.0      NaN      NaN
# ...          ...     ...      ...     ...      ...      ...      ...
# 3987  2020-12-27     NaN      3.1    13.0     44.0     63.0     23.0
# 3988  2020-12-28     NaN      1.6     6.0     27.0     37.0      4.0
# 3989  2020-12-29     NaN      1.5     5.0     15.0     16.0      8.0
# 3990  2020-12-30     NaN      1.3     3.0     20.0     25.0      2.0
# 3991  2020-12-31     NaN      1.5     7.0     40.0     51.0     21.0
#
#       PM10 max  PM2.5 max  SO2 max        CO       H2S        NO        NO2  \
# 0          NaN        NaN      1.0  0.200000  1.108333  1.000000   2.625000
# 1          NaN        NaN      1.0  0.200000  1.137500  2.250000  12.916667
# 2          NaN        NaN      7.0  0.204167  1.158333  3.625000  22.166667
# 3          NaN        NaN      4.0  0.200000  1.382609  8.217391  28.304348
# 4          NaN        NaN      2.0  0.220833  1.037500  5.750000  24.958333
# ...        ...        ...      ...       ...       ...       ...        ...
# 3987      28.0       24.0      5.0       NaN  1.408333  2.833333  13.625000
# 3988      26.0        6.0      9.0       NaN  1.208333  1.541667   7.833333
# 3989      14.0        9.0      4.0       NaN  1.150000  1.250000   6.791667
# 3990      42.0        5.0      1.0       NaN  1.120833  1.208333   5.458333
# 3991      27.0       22.0      1.0       NaN  1.175000  1.500000  10.791667
#
#             NOx       PM1       PM10     PM2.5       SO2 data_lectura  \
# 0           NaN       NaN        NaN       NaN  1.000000   2010-01-01
# 1           NaN       NaN        NaN       NaN  1.000000   2010-01-02
# 2           NaN       NaN        NaN       NaN  1.875000   2010-01-03
# 3           NaN       NaN        NaN       NaN  1.652174   2010-01-04
# 4           NaN       NaN        NaN       NaN  1.083333   2010-01-05
# ...         ...       ...        ...       ...       ...          ...
# 3987  17.416667  8.291667  10.458333  8.916667  1.500000   2020-12-27
# 3988   9.666667  2.083333   7.541667  3.083333  5.416667   2020-12-28
# 3989   8.166667  2.458333   4.708333  3.208333  2.333333   2020-12-29
# 3990   6.916667  1.416667   7.500000  2.250000  1.000000   2020-12-30
# 3991  12.583333  5.958333   8.916667  6.708333  1.000000   2020-12-31
#
#       Pressió atmosfèrica màxima  Pressió atmosfèrica mínima  \
# 0                    1003.531915                 1002.680851
# 1                    1016.875000                 1016.312500
# 2                    1016.458333                 1016.125000
# 3                    1008.625000                 1008.354167
# 4                    1000.083333                  999.833333
# ...                          ...                         ...
# 3987                 1009.404167                 1008.766667
# 3988                  995.566667                  994.956250
# 3989                 1001.879167                 1001.518750
# 3990                 1010.639583                 1010.081250
# 3991                 1011.370833                 1011.060417
#
#       Humitat relativa màxima  Velocitat del vent a 10 m (esc.)  \
# 0                   45.191489                          5.848936
# 1                   57.020833                          3.537500
# 2                   79.250000                          1.527083
# 3                   82.583333                          1.802083
# 4                   86.187500                          1.868750
# ...                       ...                               ...
# 3987                65.937500                          1.931250
# 3988                49.062500                          5.014583
# 3989                47.687500                          3.875000
# 3990                49.250000                          6.022917
# 3991                55.145833                          2.810417
#
#       Direcció de vent 10 m (m. 1)  Temperatura  Humitat relativa  \
# 0                       267.234043    11.278723         44.170213
# 1                       220.875000     9.833333         55.625000
# 2                       101.083333     9.666667         78.000000
# 3                        81.458333     9.406250         81.625000
# 4                       158.625000     9.716667         85.458333
# ...                            ...          ...               ...
# 3987                    217.395833     6.831250         63.083333
# 3988                    265.958333    10.668750         47.375000
# 3989                    258.208333    10.533333         46.104167
# 3990                    295.020833     9.764583         48.312500
# 3991                    261.875000    10.129167         53.770833
#
#       Pressió atmosfèrica  Precipitació  Irradiància solar global  \
# 0             1003.127660      0.000000                 71.574468
# 1             1016.645833      0.000000                 61.458333
# 2             1016.312500      0.000000                 93.895833
# 3             1008.500000      0.250000                 36.604167
# 4              999.979167      0.079167                 14.375000
# ...                   ...           ...                       ...
# 3987          1009.087500      0.000000                 59.062500
# 3988           995.262500      0.000000                106.604167
# 3989          1001.689583      0.000000                 91.479167
# 3990          1010.368750      0.000000                 77.208333
# 3991          1011.212500      0.000000                 97.291667
#
#       Temperatura màxima  Temperatura mínima  Humitat relativa mínima  \
# 0              11.444681           11.102128                43.042553
# 1              10.056250            9.604167                54.312500
# 2               9.927083            9.418750                76.687500
# 3               9.572917            9.233333                80.500000
# 4               9.787500            9.654167                84.625000
# ...                  ...                 ...                      ...
# 3987            7.322917            6.295833                60.708333
# 3988           10.983333           10.360417                45.750000
# 3989           10.879167           10.147917                44.708333
# 3990            9.947917            9.558333                47.354167
# 3991           10.443750            9.833333                52.333333
#
#       Ratxa màxima del vent a 10 m  \
# 0                        12.021277
# 1                         6.714583
# 2                         2.870833
# 3                         3.570833
# 4                         3.497917
# ...                            ...
# 3987                      4.272917
# 3988                     10.270833
# 3989                      8.314583
# 3990                     12.089583
# 3991                      5.789583
#
#       Direcció de la ratxa màxima del vent a 10 m  \
# 0                                      271.957447
# 1                                      216.187500
# 2                                      118.208333
# 3                                       82.333333
# 4                                      174.458333
# ...                                           ...
# 3987                                   240.083333
# 3988                                   269.041667
# 3989                                   270.229167
# 3990                                   293.333333
# 3991                                   272.229167
#
#       Precipitació màxima en 1 minut
# 0                           0.000000
# 1                           0.000000
# 2                           0.000000
# 3                           0.027083
# 4                           0.022917
# ...                              ...
# 3987                        0.000000
# 3988                        0.000000
# 3989                        0.000000
# 3990                        0.000000
# 3991                        0.000000
#
# [3992 rows x 36 columns]

# %%
#Let's create a new column as Alert, once PM2.5 max value is upper threshold 25, as state in pollutant norm.
df['Alert'] = ["1" if a >=25 else "0" for a in df['PM2.5 max']]
#As we want to predict 24h PM2.5 pollutant, let's create and Alert 24h by moving row up in column 'Alert'
df['Alert_nxt24h'] = df['Alert'].shift(-1)
#Let's remove 'Alert' and convert 'Alert next 24h' into unique 'Alert' column 
df.drop(['Alert'], axis =1)
df['Alert']=df['Alert_nxt24h']
df=df.drop(['Alert_nxt24h'], axis =1)

# %%
#Skew distribution
skew = df.skew()
print(skew)
# Out:
# CO max                                         1.913773
# H2S max                                        4.409012
# NO max                                         2.612130
# NO2 max                                        2.000400
# NOx max                                        1.761434
# PM1 max                                        1.499718
# PM10 max                                       2.865904
# PM2.5 max                                      1.641074
# SO2 max                                        5.639295
# CO                                             1.833302
# H2S                                            2.381244
# NO                                             2.905730
# NO2                                            0.794463
# NOx                                            1.345018
# PM1                                            1.554037
# PM10                                           1.066574
# PM2.5                                          1.235994
# SO2                                            2.351289
# Pressió atmosfèrica màxima                    -0.252026
# Pressió atmosfèrica mínima                    -0.264383
# Humitat relativa màxima                       -0.594833
# Velocitat del vent a 10 m (esc.)               1.786824
# Direcció de vent 10 m (m. 1)                   0.279245
# Temperatura                                    0.039440
# Humitat relativa                              -0.533568
# Pressió atmosfèrica                           -0.254528
# Precipitació                                   8.700267
# Irradiància solar global                       0.037336
# Temperatura màxima                             0.040548
# Temperatura mínima                             0.037197
# Humitat relativa mínima                       -0.470017
# Ratxa màxima del vent a 10 m                   1.670080
# Direcció de la ratxa màxima del vent a 10 m    0.411147
# Precipitació màxima en 1 minut                 6.312992
# Alert                                          1.352396
# dtype: float64

# %% [markdown]
# #### NOTA: Not too bad distribution unless Raining features related, where it is highlighted a great non-simetric distribution of the data. Based on Feature importance impact on target, they will be scaled/removed if necessary

# %% [markdown]
# # 2. Exploratory Data Analysis

# %% [markdown]
# ## 2.1 Null values

# %%
#Find sum of duplicate data
sum(df.duplicated())
# Out:
# 0

# %%
#To look for values missed
df.isna().sum().sort_values(ascending = False)
# Out:
# CO max                                         3649
# CO                                             3649
# PM1 max                                        1354
# PM1                                            1354
# PM2.5                                           926
# PM2.5 max                                       926
# PM10                                            919
# PM10 max                                        919
# NOx max                                         669
# NOx                                             669
# NO max                                           40
# NO2 max                                          40
# NO                                               40
# NO2                                              40
# H2S max                                          31
# H2S                                              31
# SO2                                              17
# SO2 max                                          17
# Temperatura                                       5
# Temperatura mínima                                5
# Temperatura màxima                                5
# Humitat relativa                                  4
# Humitat relativa mínima                           4
# Irradiància solar global                          4
# Pressió atmosfèrica                               4
# Direcció de la ratxa màxima del vent a 10 m       4
# Direcció de vent 10 m (m. 1)                      4
# Humitat relativa màxima                           4
# Pressió atmosfèrica mínima                        4
# Pressió atmosfèrica màxima                        4
# Velocitat del vent a 10 m (esc.)                  3
# Precipitació                                      3
# data_lectura                                      3
# Ratxa màxima del vent a 10 m                      3
# Precipitació màxima en 1 minut                    3
# Alert                                             1
# data                                              0
# dtype: int64

# %% [markdown]
# #### NOTA: Let's visualize CO, PM1 and PM2.5 feature behaviours

# %%
# Let's create a graph to compare feature missing values behaviour
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
#Date type object is changed to Datetime
df['data'] = pd.to_datetime(df['data'])
df50 = df[['data','CO','PM1','PM2.5']]
figure(figsize=(15, 7), dpi=80)
plt.plot(df50['data'],df50['PM2.5'], c='r', label='PM2.5')
plt.plot(df50['data'],df50['CO'], c='b', label='CO')
plt.plot(df50['data'],df50['PM1'], c='g', label='PM1')
plt.title('Evolution PM2.5, PM1 and CO')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### CONCLUSION: Based on seen on graph above, CO data register was stopped by 01/2011, PM2.5 info available is dated from 02/2012 and there are missing PM1 registers from 2016 to middle 2017, so let's remove CO, CO max, PM1 and PM1 max features and to create a new dataset from Feb 2012 in advance.

# %%
#Let's delete CO, CO max, PM1 and PM1 max features
df0 = df.drop(['CO','CO max','PM1','PM1 max'], axis=1)

# %%
# Let's consider PM2.5 > 0 samples, because it is not possible to get PM2.5 = 0. 
df0 = df0[df0['PM2.5 max']>0]
df0
# Out:
#            data  H2S max  NO max  NO2 max  NOx max  PM10 max  PM2.5 max  \
# 743  2012-02-03      1.9    12.0     56.0     75.0      29.0       20.0
# 744  2012-02-04      1.4     7.0     37.0     46.0      59.0       14.0
# 745  2012-02-05      2.4    21.0     64.0     95.0      30.0       24.0
# 746  2012-02-06      2.1    14.0     60.0     81.0      24.0       23.0
# 747  2012-02-07      1.8     5.0     42.0     48.0      41.0        9.0
# ...         ...      ...     ...      ...      ...       ...        ...
# 3987 2020-12-27      3.1    13.0     44.0     63.0      28.0       24.0
# 3988 2020-12-28      1.6     6.0     27.0     37.0      26.0        6.0
# 3989 2020-12-29      1.5     5.0     15.0     16.0      14.0        9.0
# 3990 2020-12-30      1.3     3.0     20.0     25.0      42.0        5.0
# 3991 2020-12-31      1.5     7.0     40.0     51.0      27.0       22.0
#
#       SO2 max       H2S        NO        NO2        NOx       PM10      PM2.5  \
# 743       1.0  1.371429  3.400000  17.900000  22.900000  26.555556  14.666667
# 744       2.0  1.291667  2.583333  12.666667  15.708333  19.666667   9.125000
# 745       4.0  1.595833  4.375000  22.416667  28.500000  15.291667  11.541667
# 746       1.0  1.604545  3.900000  20.800000  26.450000  13.333333   7.458333
# 747       1.0  1.445833  2.521739  13.521739  16.869565  17.541667   5.041667
# ...       ...       ...       ...        ...        ...        ...        ...
# 3987      5.0  1.408333  2.833333  13.625000  17.416667  10.458333   8.916667
# 3988      9.0  1.208333  1.541667   7.833333   9.666667   7.541667   3.083333
# 3989      4.0  1.150000  1.250000   6.791667   8.166667   4.708333   3.208333
# 3990      1.0  1.120833  1.208333   5.458333   6.916667   7.500000   2.250000
# 3991      1.0  1.175000  1.500000  10.791667  12.583333   8.916667   6.708333
#
#            SO2 data_lectura  Pressió atmosfèrica màxima  \
# 743   1.000000   2012-02-03                 1017.964583
# 744   1.041667   2012-02-04                 1023.589583
# 745   1.166667   2012-02-05                 1022.868750
# 746   1.000000   2012-02-06                 1020.218750
# 747   1.000000   2012-02-07                 1016.256250
# ...        ...          ...                         ...
# 3987  1.500000   2020-12-27                 1009.404167
# 3988  5.416667   2020-12-28                  995.566667
# 3989  2.333333   2020-12-29                 1001.879167
# 3990  1.000000   2020-12-30                 1010.639583
# 3991  1.000000   2020-12-31                 1011.370833
#
#       Pressió atmosfèrica mínima  Humitat relativa màxima  \
# 743                  1017.591667                32.958333
# 744                  1023.091667                20.875000
# 745                  1022.466667                60.604167
# 746                  1019.852083                45.062500
# 747                  1015.714583                17.895833
# ...                          ...                      ...
# 3987                 1008.766667                65.937500
# 3988                  994.956250                49.062500
# 3989                 1001.518750                47.687500
# 3990                 1010.081250                49.250000
# 3991                 1011.060417                55.145833
#
#       Velocitat del vent a 10 m (esc.)  Direcció de vent 10 m (m. 1)  \
# 743                           5.052083                    308.125000
# 744                           4.885417                    257.541667
# 745                           2.631250                    216.541667
# 746                           3.593750                    271.000000
# 747                           5.885417                    314.208333
# ...                                ...                           ...
# 3987                          1.931250                    217.395833
# 3988                          5.014583                    265.958333
# 3989                          3.875000                    258.208333
# 3990                          6.022917                    295.020833
# 3991                          2.810417                    261.875000
#
#       Temperatura  Humitat relativa  Pressió atmosfèrica  Precipitació  \
# 743      2.714583         31.854167          1017.787500       0.00000
# 744      4.029167         19.562500          1023.345833       0.00000
# 745      3.562500         58.625000          1022.672917       0.00625
# 746      7.995833         42.979167          1020.043750       0.00000
# 747      8.281250         16.812500          1016.004167       0.00000
# ...           ...               ...                  ...           ...
# 3987     6.831250         63.083333          1009.087500       0.00000
# 3988    10.668750         47.375000           995.262500       0.00000
# 3989    10.533333         46.104167          1001.689583       0.00000
# 3990     9.764583         48.312500          1010.368750       0.00000
# 3991    10.129167         53.770833          1011.212500       0.00000
#
#       Irradiància solar global  Temperatura màxima  Temperatura mínima  \
# 743                 149.166667            3.029167            2.393750
# 744                 155.916667            4.433333            3.641667
# 745                  44.104167            3.858333            3.204167
# 746                 162.291667            8.452083            7.497917
# 747                 166.458333            8.608333            7.958333
# ...                        ...                 ...                 ...
# 3987                 59.062500            7.322917            6.295833
# 3988                106.604167           10.983333           10.360417
# 3989                 91.479167           10.879167           10.147917
# 3990                 77.208333            9.947917            9.558333
# 3991                 97.291667           10.443750            9.833333
#
#       Humitat relativa mínima  Ratxa màxima del vent a 10 m  \
# 743                 30.854167                      9.572917
# 744                 18.250000                      9.700000
# 745                 56.833333                      5.316667
# 746                 41.125000                      7.177083
# 747                 15.812500                     11.408333
# ...                       ...                           ...
# 3987                60.708333                      4.272917
# 3988                45.750000                     10.270833
# 3989                44.708333                      8.314583
# 3990                47.354167                     12.089583
# 3991                52.333333                      5.789583
#
#       Direcció de la ratxa màxima del vent a 10 m  \
# 743                                    302.041667
# 744                                    286.125000
# 745                                    213.354167
# 746                                    275.854167
# 747                                    305.000000
# ...                                           ...
# 3987                                   240.083333
# 3988                                   269.041667
# 3989                                   270.229167
# 3990                                   293.333333
# 3991                                   272.229167
#
#       Precipitació màxima en 1 minut Alert
# 743                          0.00000     0
# 744                          0.00000     0
# 745                          0.00625     0
# 746                          0.00000     0
# 747                          0.00000     0
# ...                              ...   ...
# 3987                         0.00000     0
# 3988                         0.00000     0
# 3989                         0.00000     0
# 3990                         0.00000     0
# 3991                         0.00000   NaN
#
# [3063 rows x 33 columns]

# %%
#Let's check new shape
df0.shape
# Out:
# (3063, 33)

# %%
#To look for values missed
df0.isna().sum().sort_values(ascending = False)
# Out:
# NOx max                                        52
# NOx                                            52
# NO                                             37
# NO max                                         37
# NO2 max                                        37
# NO2                                            37
# H2S                                            24
# H2S max                                        24
# SO2                                            17
# SO2 max                                        17
# Temperatura màxima                              5
# Temperatura                                     5
# Temperatura mínima                              5
# Humitat relativa màxima                         4
# Irradiància solar global                        4
# Pressió atmosfèrica                             4
# Humitat relativa                                4
# Direcció de vent 10 m (m. 1)                    4
# Pressió atmosfèrica màxima                      4
# Pressió atmosfèrica mínima                      4
# Direcció de la ratxa màxima del vent a 10 m     4
# Humitat relativa mínima                         4
# Velocitat del vent a 10 m (esc.)                3
# data_lectura                                    3
# Ratxa màxima del vent a 10 m                    3
# Precipitació                                    3
# Precipitació màxima en 1 minut                  3
# PM10                                            2
# PM10 max                                        2
# Alert                                           1
# PM2.5                                           0
# PM2.5 max                                       0
# data                                            0
# dtype: int64

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3063 entries, 743 to 3991
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   data                                         3063 non-null   datetime64[ns]
#  1   H2S max                                      3039 non-null   float64
#  2   NO max                                       3026 non-null   float64
#  3   NO2 max                                      3026 non-null   float64
#  4   NOx max                                      3011 non-null   float64
#  5   PM10 max                                     3061 non-null   float64
#  6   PM2.5 max                                    3063 non-null   float64
#  7   SO2 max                                      3046 non-null   float64
#  8   H2S                                          3039 non-null   float64
#  9   NO                                           3026 non-null   float64
#  10  NO2                                          3026 non-null   float64
#  11  NOx                                          3011 non-null   float64
#  12  PM10                                         3061 non-null   float64
#  13  PM2.5                                        3063 non-null   float64
#  14  SO2                                          3046 non-null   float64
#  15  data_lectura                                 3060 non-null   object
#  16  Pressió atmosfèrica màxima                   3059 non-null   float64
#  17  Pressió atmosfèrica mínima                   3059 non-null   float64
#  18  Humitat relativa màxima                      3059 non-null   float64
#  19  Velocitat del vent a 10 m (esc.)             3060 non-null   float64
#  20  Direcció de vent 10 m (m. 1)                 3059 non-null   float64
#  21  Temperatura                                  3058 non-null   float64
#  22  Humitat relativa                             3059 non-null   float64
#  23  Pressió atmosfèrica                          3059 non-null   float64
#  24  Precipitació                                 3060 non-null   float64
#  25  Irradiància solar global                     3059 non-null   float64
#  26  Temperatura màxima                           3058 non-null   float64
#  27  Temperatura mínima                           3058 non-null   float64
#  28  Humitat relativa mínima                      3059 non-null   float64
#  29  Ratxa màxima del vent a 10 m                 3060 non-null   float64
#  30  Direcció de la ratxa màxima del vent a 10 m  3059 non-null   float64
#  31  Precipitació màxima en 1 minut               3060 non-null   float64
#  32  Alert                                        3062 non-null   object
# dtypes: datetime64[ns](1), float64(30), object(2)
# memory usage: 813.6+ KB

# %%
# NA data strategies to be managed. Drop or fill. 
dfA = df0.dropna()
dfB = df0.fillna(method = 'ffill')

# %%
print(dfA['Alert'].value_counts())
print(dfB['Alert'].value_counts())
# Out:
# 0    2122
# 1     856
# Name: Alert, dtype: int64
# 0    2191
# 1     872
# Name: Alert, dtype: int64

# %% [markdown]
# #### NOTA: I compare impact on deleting NA data by removing or fill, in comparison with Alert feature, due to an unbalanced dataset I have, let's prioritize to fill data in order not to lose Data.

# %%
#I can fill forward and backward methods, so let's use forward method to remove last NAN in dataset because backward filling NAN's in last raw cannot be filled, unless we increase data window. (not the case).
df0 = df0.fillna(method = 'ffill')

# %%
#Let's change Alert type data
df0['Alert']=df0['Alert'].astype('int')

# %%
#Check dataframe
df0
# Out:
#            data  H2S max  NO max  NO2 max  NOx max  PM10 max  PM2.5 max  \
# 743  2012-02-03      1.9    12.0     56.0     75.0      29.0       20.0
# 744  2012-02-04      1.4     7.0     37.0     46.0      59.0       14.0
# 745  2012-02-05      2.4    21.0     64.0     95.0      30.0       24.0
# 746  2012-02-06      2.1    14.0     60.0     81.0      24.0       23.0
# 747  2012-02-07      1.8     5.0     42.0     48.0      41.0        9.0
# ...         ...      ...     ...      ...      ...       ...        ...
# 3987 2020-12-27      3.1    13.0     44.0     63.0      28.0       24.0
# 3988 2020-12-28      1.6     6.0     27.0     37.0      26.0        6.0
# 3989 2020-12-29      1.5     5.0     15.0     16.0      14.0        9.0
# 3990 2020-12-30      1.3     3.0     20.0     25.0      42.0        5.0
# 3991 2020-12-31      1.5     7.0     40.0     51.0      27.0       22.0
#
#       SO2 max       H2S        NO        NO2        NOx       PM10      PM2.5  \
# 743       1.0  1.371429  3.400000  17.900000  22.900000  26.555556  14.666667
# 744       2.0  1.291667  2.583333  12.666667  15.708333  19.666667   9.125000
# 745       4.0  1.595833  4.375000  22.416667  28.500000  15.291667  11.541667
# 746       1.0  1.604545  3.900000  20.800000  26.450000  13.333333   7.458333
# 747       1.0  1.445833  2.521739  13.521739  16.869565  17.541667   5.041667
# ...       ...       ...       ...        ...        ...        ...        ...
# 3987      5.0  1.408333  2.833333  13.625000  17.416667  10.458333   8.916667
# 3988      9.0  1.208333  1.541667   7.833333   9.666667   7.541667   3.083333
# 3989      4.0  1.150000  1.250000   6.791667   8.166667   4.708333   3.208333
# 3990      1.0  1.120833  1.208333   5.458333   6.916667   7.500000   2.250000
# 3991      1.0  1.175000  1.500000  10.791667  12.583333   8.916667   6.708333
#
#            SO2 data_lectura  Pressió atmosfèrica màxima  \
# 743   1.000000   2012-02-03                 1017.964583
# 744   1.041667   2012-02-04                 1023.589583
# 745   1.166667   2012-02-05                 1022.868750
# 746   1.000000   2012-02-06                 1020.218750
# 747   1.000000   2012-02-07                 1016.256250
# ...        ...          ...                         ...
# 3987  1.500000   2020-12-27                 1009.404167
# 3988  5.416667   2020-12-28                  995.566667
# 3989  2.333333   2020-12-29                 1001.879167
# 3990  1.000000   2020-12-30                 1010.639583
# 3991  1.000000   2020-12-31                 1011.370833
#
#       Pressió atmosfèrica mínima  Humitat relativa màxima  \
# 743                  1017.591667                32.958333
# 744                  1023.091667                20.875000
# 745                  1022.466667                60.604167
# 746                  1019.852083                45.062500
# 747                  1015.714583                17.895833
# ...                          ...                      ...
# 3987                 1008.766667                65.937500
# 3988                  994.956250                49.062500
# 3989                 1001.518750                47.687500
# 3990                 1010.081250                49.250000
# 3991                 1011.060417                55.145833
#
#       Velocitat del vent a 10 m (esc.)  Direcció de vent 10 m (m. 1)  \
# 743                           5.052083                    308.125000
# 744                           4.885417                    257.541667
# 745                           2.631250                    216.541667
# 746                           3.593750                    271.000000
# 747                           5.885417                    314.208333
# ...                                ...                           ...
# 3987                          1.931250                    217.395833
# 3988                          5.014583                    265.958333
# 3989                          3.875000                    258.208333
# 3990                          6.022917                    295.020833
# 3991                          2.810417                    261.875000
#
#       Temperatura  Humitat relativa  Pressió atmosfèrica  Precipitació  \
# 743      2.714583         31.854167          1017.787500       0.00000
# 744      4.029167         19.562500          1023.345833       0.00000
# 745      3.562500         58.625000          1022.672917       0.00625
# 746      7.995833         42.979167          1020.043750       0.00000
# 747      8.281250         16.812500          1016.004167       0.00000
# ...           ...               ...                  ...           ...
# 3987     6.831250         63.083333          1009.087500       0.00000
# 3988    10.668750         47.375000           995.262500       0.00000
# 3989    10.533333         46.104167          1001.689583       0.00000
# 3990     9.764583         48.312500          1010.368750       0.00000
# 3991    10.129167         53.770833          1011.212500       0.00000
#
#       Irradiància solar global  Temperatura màxima  Temperatura mínima  \
# 743                 149.166667            3.029167            2.393750
# 744                 155.916667            4.433333            3.641667
# 745                  44.104167            3.858333            3.204167
# 746                 162.291667            8.452083            7.497917
# 747                 166.458333            8.608333            7.958333
# ...                        ...                 ...                 ...
# 3987                 59.062500            7.322917            6.295833
# 3988                106.604167           10.983333           10.360417
# 3989                 91.479167           10.879167           10.147917
# 3990                 77.208333            9.947917            9.558333
# 3991                 97.291667           10.443750            9.833333
#
#       Humitat relativa mínima  Ratxa màxima del vent a 10 m  \
# 743                 30.854167                      9.572917
# 744                 18.250000                      9.700000
# 745                 56.833333                      5.316667
# 746                 41.125000                      7.177083
# 747                 15.812500                     11.408333
# ...                       ...                           ...
# 3987                60.708333                      4.272917
# 3988                45.750000                     10.270833
# 3989                44.708333                      8.314583
# 3990                47.354167                     12.089583
# 3991                52.333333                      5.789583
#
#       Direcció de la ratxa màxima del vent a 10 m  \
# 743                                    302.041667
# 744                                    286.125000
# 745                                    213.354167
# 746                                    275.854167
# 747                                    305.000000
# ...                                           ...
# 3987                                   240.083333
# 3988                                   269.041667
# 3989                                   270.229167
# 3990                                   293.333333
# 3991                                   272.229167
#
#       Precipitació màxima en 1 minut  Alert
# 743                          0.00000      0
# 744                          0.00000      0
# 745                          0.00625      0
# 746                          0.00000      0
# 747                          0.00000      0
# ...                              ...    ...
# 3987                         0.00000      0
# 3988                         0.00000      0
# 3989                         0.00000      0
# 3990                         0.00000      0
# 3991                         0.00000      0
#
# [3063 rows x 33 columns]

# %%
#Let's confirm features type
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3063 entries, 743 to 3991
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   data                                         3063 non-null   datetime64[ns]
#  1   H2S max                                      3063 non-null   float64
#  2   NO max                                       3063 non-null   float64
#  3   NO2 max                                      3063 non-null   float64
#  4   NOx max                                      3063 non-null   float64
#  5   PM10 max                                     3063 non-null   float64
#  6   PM2.5 max                                    3063 non-null   float64
#  7   SO2 max                                      3063 non-null   float64
#  8   H2S                                          3063 non-null   float64
#  9   NO                                           3063 non-null   float64
#  10  NO2                                          3063 non-null   float64
#  11  NOx                                          3063 non-null   float64
#  12  PM10                                         3063 non-null   float64
#  13  PM2.5                                        3063 non-null   float64
#  14  SO2                                          3063 non-null   float64
#  15  data_lectura                                 3063 non-null   object
#  16  Pressió atmosfèrica màxima                   3063 non-null   float64
#  17  Pressió atmosfèrica mínima                   3063 non-null   float64
#  18  Humitat relativa màxima                      3063 non-null   float64
#  19  Velocitat del vent a 10 m (esc.)             3063 non-null   float64
#  20  Direcció de vent 10 m (m. 1)                 3063 non-null   float64
#  21  Temperatura                                  3063 non-null   float64
#  22  Humitat relativa                             3063 non-null   float64
#  23  Pressió atmosfèrica                          3063 non-null   float64
#  24  Precipitació                                 3063 non-null   float64
#  25  Irradiància solar global                     3063 non-null   float64
#  26  Temperatura màxima                           3063 non-null   float64
#  27  Temperatura mínima                           3063 non-null   float64
#  28  Humitat relativa mínima                      3063 non-null   float64
#  29  Ratxa màxima del vent a 10 m                 3063 non-null   float64
#  30  Direcció de la ratxa màxima del vent a 10 m  3063 non-null   float64
#  31  Precipitació màxima en 1 minut               3063 non-null   float64
#  32  Alert                                        3063 non-null   int64
# dtypes: datetime64[ns](1), float64(30), int64(1), object(1)
# memory usage: 813.6+ KB

# %%
#Let's create some graphs interesting for FrontEnd summarized by years, in order to provide some pollutant's information for user 
df66=df0.groupby(df0['data'].dt.year).mean()
df66
# Out:
#        H2S max     NO max    NO2 max    NOx max   PM10 max  PM2.5 max  \
# data
# 2012  2.422082  21.044164  51.889590  80.750789  34.880126  20.908517
# 2013  2.476519  19.533149  45.254144  71.638122  30.762431  19.292818
# 2014  2.900556  25.891667  48.011111  84.644444  30.266667  20.561111
# 2015  3.549550  26.672673  52.081081  88.303303  39.084084  23.729730
# 2016  3.040476  21.952381  40.544218  70.125850  33.595238  19.040816
# 2017  3.133151  19.923288  49.106849  75.539726  36.915068  20.890411
# 2018  2.962171  22.286184  52.394737  83.832237  37.703947  20.250000
# 2019  2.777961  16.556474  47.363636  69.939394  38.853994  19.732782
# 2020  2.156438  14.871233  38.764384  59.312329  33.701370  18.641096
#
#        SO2 max       H2S        NO        NO2        NOx       PM10  \
# data
# 2012  6.271293  1.483850  4.620920  21.863747  28.407204  18.754260
# 2013  2.925414  1.562165  4.672305  18.868821  25.466330  15.533681
# 2014  6.463889  1.875456  5.845098  20.594331  29.948544  16.515508
# 2015  5.783784  1.782203  6.404812  23.122739  32.458423  22.282271
# 2016  6.887755  1.777953  5.826332  18.764996  27.206466  17.232000
# 2017  6.328767  1.643339  5.043679  22.437935  29.522541  19.145392
# 2018  4.891447  1.646755  4.951121  22.096756  29.237562  19.196313
# 2019  7.126722  1.423804  3.598965  18.260422  23.205922  19.385099
# 2020  3.934247  1.258778  3.567747  15.889818  20.977562  15.229841
#
#           PM2.5       SO2  Pressió atmosfèrica màxima  \
# data
# 2012  11.616185  2.107521                 1015.922780
# 2013   9.827055  1.478884                 1015.201571
# 2014  10.998351  3.359932                 1014.800822
# 2015  13.696468  2.990940                 1018.478166
# 2016  10.481345  3.286824                 1016.926377
# 2017  11.583118  3.325518                 1017.957363
# 2018  11.147602  2.626252                 1015.372766
# 2019  10.524039  3.308902                 1015.910451
# 2020   9.429262  2.415301                 1017.259587
#
#       Pressió atmosfèrica mínima  Humitat relativa màxima  \
# data
# 2012                 1015.622135                70.559427
# 2013                 1014.883892                68.009151
# 2014                 1014.490382                72.159722
# 2015                 1018.178691                70.410723
# 2016                 1016.638607                71.962782
# 2017                 1017.659378                69.273052
# 2018                 1015.070367                71.605469
# 2019                 1015.599306                69.637339
# 2020                 1016.963161                74.188216
#
#       Velocitat del vent a 10 m (esc.)  Direcció de vent 10 m (m. 1)  \
# data
# 2012                          2.369237                    169.045837
# 2013                          2.604443                    180.880755
# 2014                          2.401158                    162.817297
# 2015                          2.351038                    164.411207
# 2016                          2.287050                    156.085242
# 2017                          2.297795                    168.729218
# 2018                          2.321978                    167.755071
# 2019                          2.419381                    168.588499
# 2020                          2.297740                    160.911025
#
#       Temperatura  Humitat relativa  Pressió atmosfèrica  Precipitació  \
# data
# 2012    17.720831         68.488258          1015.773970      0.026656
# 2013    16.732637         66.187615          1015.046196      0.035963
# 2014    17.274317         70.386285          1014.648466      0.031476
# 2015    17.284453         68.569132          1018.329073      0.025507
# 2016    17.799526         69.958648          1016.788287      0.025716
# 2017    17.292405         67.206735          1017.808995      0.015805
# 2018    16.720285         69.595600          1015.222718      0.046395
# 2019    17.183626         67.507289          1015.756503      0.020655
# 2020    17.325285         72.007406          1017.112548      0.029612
#
#       Irradiància solar global  Temperatura màxima  Temperatura mínima  \
# data
# 2012                210.035607           18.112342           17.349750
# 2013                201.798343           17.119866           16.364416
# 2014                195.194097           17.641765           16.922650
# 2015                207.390328           17.664915           16.921034
# 2016                204.612741           18.174946           17.415870
# 2017                204.547888           17.696599           16.918665
# 2018                183.181812           17.102255           16.357353
# 2019                199.698290           17.576900           16.807782
# 2020                192.288341           17.688207           16.978432
#
#       Humitat relativa mínima  Ratxa màxima del vent a 10 m  \
# data
# 2012                66.364770                      4.649357
# 2013                64.330974                      5.157592
# 2014                68.605845                      4.759038
# 2015                66.702578                      4.646324
# 2016                67.949939                      4.557771
# 2017                65.183404                      4.578494
# 2018                67.557155                      4.655332
# 2019                65.345099                      4.881548
# 2020                69.813550                      4.618169
#
#       Direcció de la ratxa màxima del vent a 10 m  \
# data
# 2012                                   169.368814
# 2013                                   181.944947
# 2014                                   162.771925
# 2015                                   162.208625
# 2016                                   156.595509
# 2017                                   168.079110
# 2018                                   167.418586
# 2019                                   167.245064
# 2020                                   158.344678
#
#       Precipitació màxima en 1 minut     Alert
# data
# 2012                        0.004397  0.296530
# 2013                        0.005122  0.273481
# 2014                        0.005828  0.300000
# 2015                        0.004392  0.378378
# 2016                        0.004932  0.227891
# 2017                        0.003339  0.293151
# 2018                        0.008141  0.279605
# 2019                        0.003937  0.256198
# 2020                        0.005896  0.254795

# %%
# Pollutant PM2.5
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(15, 7), dpi=80)
plt.plot(df66['PM2.5'],c='r', label='PM2.5')
plt.plot(df66['PM2.5 max'],c='b',label='PM2.5 max')
plt.xlabel('Years')
plt.ylabel('microgr/m3')
plt.title('Evolution PM2.5')
plt.legend()
plt.savefig("FrontEnd_docs_related/PM2.5.jpg", bbox_inches='tight');

# %%
#Pollutant PM10
figure(figsize=(15, 7), dpi=80)
plt.plot(df66['PM10'],c='r', label='PM10')
plt.plot(df66['PM10 max'],c='b',label='PM10 max')
plt.xlabel('Years')
plt.ylabel('microgr/m3')
plt.title('Evolution PM10')
plt.legend()
plt.savefig("FrontEnd_docs_related/PM10.jpg", bbox_inches='tight');

# %%
#Pollutant NO2
figure(figsize=(15, 7), dpi=80)
plt.plot(df66['NO2'],c='r', label='NO2')
plt.plot(df66['NO2 max'],c='b',label='NO2 max')
plt.xlabel('Years')
plt.ylabel('microgr/m3')
plt.title('Evolution NO2')
plt.legend()
plt.savefig("FrontEnd_docs_related/NO2.jpg", bbox_inches='tight');

# %%
# Pollutant H2S
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(15, 7), dpi=80)
plt.plot(df66['H2S'],c='r', label='H2S')
plt.plot(df66['H2S max'],c='b',label='H2S max')
plt.xlabel('Years')
plt.ylabel('microgr/m3')
plt.title('Evolution H2S')
plt.legend()
plt.savefig("FrontEnd_docs_related/H2S.jpg", bbox_inches='tight');

# %%
# Pollutant SO2
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(15, 7), dpi=80)
plt.plot(df66['SO2'],c='r', label='SO2')
plt.plot(df66['SO2 max'],c='b',label='SO2 max')
plt.xlabel('Years')
plt.ylabel('microgr/m3')
plt.title('Evolution SO2')
plt.legend()
plt.savefig("FrontEnd_docs_related/SO2.jpg", bbox_inches='tight');

# %%
# Pollutant NO
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(15, 7), dpi=80)
plt.plot(df66['NO'],c='r', label='NO')
plt.plot(df66['NO max'],c='b',label='NO max')
plt.xlabel('Years')
plt.ylabel('microgr/m3')
plt.title('Evolution NO')
plt.legend()
plt.savefig("FrontEnd_docs_related/NO.jpg", bbox_inches='tight');

# %%
# Pollutant NOx
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(15, 7), dpi=80)
plt.plot(df66['NOx'],c='r', label='NOx')
plt.plot(df66['NOx max'],c='b',label='NOx max')
plt.xlabel('Years')
plt.ylabel('microgr/m3')
plt.title('Evolution NOx')
plt.legend()
plt.savefig("FrontEnd_docs_related/NOx.jpg", bbox_inches='tight');

# %%
# Review values status and quartiles in order to find inconsistency data
df0.describe()
# Out:
#            H2S max       NO max      NO2 max      NOx max     PM10 max  \
# count  3063.000000  3063.000000  3063.000000  3063.000000  3063.000000
# mean      2.815540    20.856676    47.199478    75.781587    35.038198
# std       1.781291    24.134056    22.620814    51.230926    19.259940
# min       1.000000     0.000000     0.000000     0.000000     4.000000
# 25%       1.700000     5.000000    32.000000    41.000000    23.000000
# 50%       2.400000    13.000000    45.000000    63.000000    32.000000
# 75%       3.400000    27.000000    60.000000    98.000000    43.000000
# max      28.300000   200.000000   396.000000   421.000000   263.000000
#
#         PM2.5 max      SO2 max          H2S           NO          NO2  \
# count  3063.00000  3063.000000  3063.000000  3063.000000  3063.000000
# mean     20.32713     5.597453     1.601034     4.917049    20.152673
# std      12.02200     6.754843     0.641040     5.132810     9.881732
# min       2.00000     0.000000     0.795238     0.000000     0.000000
# 25%      12.00000     1.000000     1.158333     1.916667    12.744565
# 50%      18.00000     4.000000     1.425000     3.041667    18.666667
# 75%      26.00000     7.000000     1.816667     5.708333    26.333333
# max     141.00000   144.000000     6.637500    48.708333    61.888889
#
#                NOx         PM10        PM2.5          SO2  \
# count  3063.000000  3063.000000  3063.000000  3063.000000
# mean     27.279541    18.093212    11.008876     2.765340
# std      16.690552     8.956376     6.464967     2.185953
# min       0.000000     2.791667     1.208333     0.000000
# 25%      15.416667    11.625000     6.250000     1.000000
# 50%      23.125000    16.958333     9.863636     1.958333
# 75%      35.183333    22.808877    14.148551     3.833333
# max     125.541667    78.666667    51.000000    22.000000
#
#        Pressió atmosfèrica màxima  Pressió atmosfèrica mínima  \
# count                 3063.000000                 3063.000000
# mean                  1016.425521                 1016.122476
# std                      6.688192                    6.729879
# min                    986.314583                  985.758333
# 25%                   1012.780208                 1012.469792
# 50%                   1016.435417                 1016.160417
# 75%                   1020.253125                 1019.965625
# max                   1039.285417                 1038.897917
#
#        Humitat relativa màxima  Velocitat del vent a 10 m (esc.)  \
# count              3063.000000                       3063.000000
# mean                 70.838315                          2.375138
# std                  12.499852                          1.170456
# min                  17.895833                          0.739130
# 25%                  62.739583                          1.660417
# 50%                  73.458333                          1.977083
# 75%                  80.025568                          2.729167
# max                  99.375000                          8.758333
#
#        Direcció de vent 10 m (m. 1)  Temperatura  Humitat relativa  \
# count                   3063.000000  3063.000000       3063.000000
# mean                     166.775201    17.250518         68.849654
# std                       63.700290     5.917196         12.545302
# min                       22.062500     2.714583         16.812500
# 25%                      119.093750    12.185417         60.395833
# 50%                      157.604167    16.800000         71.354167
# 75%                      214.395833    22.553125         78.145833
# max                      314.208333    29.443750         99.041667
#
#        Pressió atmosfèrica  Precipitació  Irradiància solar global  \
# count          3063.000000   3063.000000               3063.000000
# mean           1016.276049      0.028414                199.850559
# std               6.704397      0.136884                 96.600553
# min             986.027083      0.000000                  0.000000
# 25%            1012.627083      0.000000                113.708333
# 50%            1016.300000      0.000000                194.145833
# 75%            1020.126042      0.000000                286.604167
# max            1039.106250      2.233333                376.979167
#
#        Temperatura màxima  Temperatura mínima  Humitat relativa mínima  \
# count         3063.000000         3063.000000              3063.000000
# mean            17.633315           16.884497                66.844376
# std              5.914163            5.932043                12.556276
# min              3.029167            2.393750                15.812500
# 25%             12.570833           11.796875                58.020833
# 50%             17.160417           16.450000                69.083333
# 75%             22.930208           22.175000                76.229167
# max             29.906250           29.012500                98.604167
#
#        Ratxa màxima del vent a 10 m  \
# count                   3063.000000
# mean                       4.729142
# std                        2.243170
# min                        1.813043
# 25%                        3.275000
# 50%                        3.918750
# 75%                        5.523958
# max                       16.502083
#
#        Direcció de la ratxa màxima del vent a 10 m  \
# count                                  3063.000000
# mean                                    166.162690
# std                                      62.888680
# min                                      33.729167
# 25%                                     118.208333
# 50%                                     153.104167
# 75%                                     212.843750
# max                                     315.854167
#
#        Precipitació màxima en 1 minut        Alert
# count                     3063.000000  3063.000000
# mean                         0.005071     0.284688
# std                          0.018746     0.451339
# min                          0.000000     0.000000
# 25%                          0.000000     0.000000
# 50%                          0.000000     0.000000
# 75%                          0.000000     1.000000
# max                          0.279167     1.000000

# %% [markdown]
# #### NOTA: Quartiles are quite regular and well distributed

# %%
#Let's reset index and delete DATA column, once merged, date is not relevant. 
df0 = df0.reset_index()
df0 = df0.drop(['index','data','data_lectura'], axis=1)
df0
# Out:
#       H2S max  NO max  NO2 max  NOx max  PM10 max  PM2.5 max  SO2 max  \
# 0         1.9    12.0     56.0     75.0      29.0       20.0      1.0
# 1         1.4     7.0     37.0     46.0      59.0       14.0      2.0
# 2         2.4    21.0     64.0     95.0      30.0       24.0      4.0
# 3         2.1    14.0     60.0     81.0      24.0       23.0      1.0
# 4         1.8     5.0     42.0     48.0      41.0        9.0      1.0
# ...       ...     ...      ...      ...       ...        ...      ...
# 3058      3.1    13.0     44.0     63.0      28.0       24.0      5.0
# 3059      1.6     6.0     27.0     37.0      26.0        6.0      9.0
# 3060      1.5     5.0     15.0     16.0      14.0        9.0      4.0
# 3061      1.3     3.0     20.0     25.0      42.0        5.0      1.0
# 3062      1.5     7.0     40.0     51.0      27.0       22.0      1.0
#
#            H2S        NO        NO2        NOx       PM10      PM2.5  \
# 0     1.371429  3.400000  17.900000  22.900000  26.555556  14.666667
# 1     1.291667  2.583333  12.666667  15.708333  19.666667   9.125000
# 2     1.595833  4.375000  22.416667  28.500000  15.291667  11.541667
# 3     1.604545  3.900000  20.800000  26.450000  13.333333   7.458333
# 4     1.445833  2.521739  13.521739  16.869565  17.541667   5.041667
# ...        ...       ...        ...        ...        ...        ...
# 3058  1.408333  2.833333  13.625000  17.416667  10.458333   8.916667
# 3059  1.208333  1.541667   7.833333   9.666667   7.541667   3.083333
# 3060  1.150000  1.250000   6.791667   8.166667   4.708333   3.208333
# 3061  1.120833  1.208333   5.458333   6.916667   7.500000   2.250000
# 3062  1.175000  1.500000  10.791667  12.583333   8.916667   6.708333
#
#            SO2  Pressió atmosfèrica màxima  Pressió atmosfèrica mínima  \
# 0     1.000000                 1017.964583                 1017.591667
# 1     1.041667                 1023.589583                 1023.091667
# 2     1.166667                 1022.868750                 1022.466667
# 3     1.000000                 1020.218750                 1019.852083
# 4     1.000000                 1016.256250                 1015.714583
# ...        ...                         ...                         ...
# 3058  1.500000                 1009.404167                 1008.766667
# 3059  5.416667                  995.566667                  994.956250
# 3060  2.333333                 1001.879167                 1001.518750
# 3061  1.000000                 1010.639583                 1010.081250
# 3062  1.000000                 1011.370833                 1011.060417
#
#       Humitat relativa màxima  Velocitat del vent a 10 m (esc.)  \
# 0                   32.958333                          5.052083
# 1                   20.875000                          4.885417
# 2                   60.604167                          2.631250
# 3                   45.062500                          3.593750
# 4                   17.895833                          5.885417
# ...                       ...                               ...
# 3058                65.937500                          1.931250
# 3059                49.062500                          5.014583
# 3060                47.687500                          3.875000
# 3061                49.250000                          6.022917
# 3062                55.145833                          2.810417
#
#       Direcció de vent 10 m (m. 1)  Temperatura  Humitat relativa  \
# 0                       308.125000     2.714583         31.854167
# 1                       257.541667     4.029167         19.562500
# 2                       216.541667     3.562500         58.625000
# 3                       271.000000     7.995833         42.979167
# 4                       314.208333     8.281250         16.812500
# ...                            ...          ...               ...
# 3058                    217.395833     6.831250         63.083333
# 3059                    265.958333    10.668750         47.375000
# 3060                    258.208333    10.533333         46.104167
# 3061                    295.020833     9.764583         48.312500
# 3062                    261.875000    10.129167         53.770833
#
#       Pressió atmosfèrica  Precipitació  Irradiància solar global  \
# 0             1017.787500       0.00000                149.166667
# 1             1023.345833       0.00000                155.916667
# 2             1022.672917       0.00625                 44.104167
# 3             1020.043750       0.00000                162.291667
# 4             1016.004167       0.00000                166.458333
# ...                   ...           ...                       ...
# 3058          1009.087500       0.00000                 59.062500
# 3059           995.262500       0.00000                106.604167
# 3060          1001.689583       0.00000                 91.479167
# 3061          1010.368750       0.00000                 77.208333
# 3062          1011.212500       0.00000                 97.291667
#
#       Temperatura màxima  Temperatura mínima  Humitat relativa mínima  \
# 0               3.029167            2.393750                30.854167
# 1               4.433333            3.641667                18.250000
# 2               3.858333            3.204167                56.833333
# 3               8.452083            7.497917                41.125000
# 4               8.608333            7.958333                15.812500
# ...                  ...                 ...                      ...
# 3058            7.322917            6.295833                60.708333
# 3059           10.983333           10.360417                45.750000
# 3060           10.879167           10.147917                44.708333
# 3061            9.947917            9.558333                47.354167
# 3062           10.443750            9.833333                52.333333
#
#       Ratxa màxima del vent a 10 m  \
# 0                         9.572917
# 1                         9.700000
# 2                         5.316667
# 3                         7.177083
# 4                        11.408333
# ...                            ...
# 3058                      4.272917
# 3059                     10.270833
# 3060                      8.314583
# 3061                     12.089583
# 3062                      5.789583
#
#       Direcció de la ratxa màxima del vent a 10 m  \
# 0                                      302.041667
# 1                                      286.125000
# 2                                      213.354167
# 3                                      275.854167
# 4                                      305.000000
# ...                                           ...
# 3058                                   240.083333
# 3059                                   269.041667
# 3060                                   270.229167
# 3061                                   293.333333
# 3062                                   272.229167
#
#       Precipitació màxima en 1 minut  Alert
# 0                            0.00000      0
# 1                            0.00000      0
# 2                            0.00625      0
# 3                            0.00000      0
# 4                            0.00000      0
# ...                              ...    ...
# 3058                         0.00000      0
# 3059                         0.00000      0
# 3060                         0.00000      0
# 3061                         0.00000      0
# 3062                         0.00000      0
#
# [3063 rows x 31 columns]

# %% [markdown]
# ## 2.2 DATA distribution

# %%
#Density Plots
df0.plot(kind='density', subplots=True, layout=(8,4), sharex=False, figsize=(20,20))
plt.show()

# %% [markdown]
# #### NOTA: Quite good regular and distributed graphs

# %%
# Feature Distribution BoxPlot
df0.plot(kind='box', subplots=True, layout=(8,4), sharex=False, sharey=False, figsize=(20,20))
plt.show()

# %% [markdown]
# #### NOTA: Having a look in Boxplots, it seems that there will be many outliers, so let's review later the impact of these

# %% [markdown]
# ## 2.3 CORRELATION

# %%
import seaborn as sns
corr = df0.corr()
top_features = corr.index
plt.figure(figsize=(25,25))
sns.set(font_scale = 0.75)
sns.heatmap(df0[top_features].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### NOTA:There are correlated features, that we need to analyse for removing or keeping based on their impact into Alert feature. Any feature with average, max and min value will be highly correlated.

# %%
corr = df0.corr()
corr[['Alert']].sort_values(by = 'Alert',ascending = False)\
.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_9f636_row0_col0{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_9f636_row1_col0{
#             background-color:  #3991c1;
#             color:  #000000;
#         }#T_9f636_row2_col0{
#             background-color:  #3d93c2;
#             color:  #000000;
#         }#T_9f636_row3_col0,#T_9f636_row4_col0{
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }#T_9f636_row5_col0{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_9f636_row6_col0{
#             background-color:  #71a8ce;
#             color:  #000000;
#         }#T_9f636_row7_col0{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_9f636_row8_col0{
#             background-color:  #7bacd1;
#             color:  #000000;
#         }#T_9f636_row9_col0,#T_9f636_row10_col0,#T_9f636_row11_col0,#T_9f636_row12_col0{
#             background-color:  #7dacd1;
#             color:  #000000;
#         }#T_9f636_row13_col0{
#             background-color:  #86b0d3;
#             color:  #000000;
#         }#T_9f636_row14_col0,#T_9f636_row15_col0{
#             background-color:  #a4bcda;
#             color:  #000000;
#         }#T_9f636_row16_col0{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_9f636_row17_col0{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_9f636_row18_col0{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_9f636_row19_col0{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_9f636_row20_col0{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_9f636_row21_col0{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_9f636_row22_col0{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_9f636_row23_col0{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_9f636_row24_col0{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_9f636_row25_col0{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_9f636_row26_col0,#T_9f636_row27_col0{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_9f636_row28_col0,#T_9f636_row29_col0,#T_9f636_row30_col0{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_9f636_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Alert</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f636_level0_row0" class="row_heading level0 row0" >Alert</th>
#                         <td id="T_9f636_row0_col0" class="data row0 col0" >1.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row1" class="row_heading level0 row1" >PM2.5 max</th>
#                         <td id="T_9f636_row1_col0" class="data row1 col0" >0.504004</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row2" class="row_heading level0 row2" >PM2.5</th>
#                         <td id="T_9f636_row2_col0" class="data row2 col0" >0.490586</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row3" class="row_heading level0 row3" >NO2</th>
#                         <td id="T_9f636_row3_col0" class="data row3 col0" >0.416666</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row4" class="row_heading level0 row4" >NOx</th>
#                         <td id="T_9f636_row4_col0" class="data row4 col0" >0.415268</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row5" class="row_heading level0 row5" >PM10</th>
#                         <td id="T_9f636_row5_col0" class="data row5 col0" >0.388281</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row6" class="row_heading level0 row6" >NO</th>
#                         <td id="T_9f636_row6_col0" class="data row6 col0" >0.356290</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row7" class="row_heading level0 row7" >NOx max</th>
#                         <td id="T_9f636_row7_col0" class="data row7 col0" >0.351526</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row8" class="row_heading level0 row8" >NO max</th>
#                         <td id="T_9f636_row8_col0" class="data row8 col0" >0.325844</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row9" class="row_heading level0 row9" >NO2 max</th>
#                         <td id="T_9f636_row9_col0" class="data row9 col0" >0.320647</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row10" class="row_heading level0 row10" >Pressió atmosfèrica</th>
#                         <td id="T_9f636_row10_col0" class="data row10 col0" >0.320472</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row11" class="row_heading level0 row11" >Pressió atmosfèrica mínima</th>
#                         <td id="T_9f636_row11_col0" class="data row11 col0" >0.320367</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row12" class="row_heading level0 row12" >Pressió atmosfèrica màxima</th>
#                         <td id="T_9f636_row12_col0" class="data row12 col0" >0.320359</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row13" class="row_heading level0 row13" >PM10 max</th>
#                         <td id="T_9f636_row13_col0" class="data row13 col0" >0.287922</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row14" class="row_heading level0 row14" >Humitat relativa mínima</th>
#                         <td id="T_9f636_row14_col0" class="data row14 col0" >0.191002</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row15" class="row_heading level0 row15" >Humitat relativa</th>
#                         <td id="T_9f636_row15_col0" class="data row15 col0" >0.188925</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row16" class="row_heading level0 row16" >Humitat relativa màxima</th>
#                         <td id="T_9f636_row16_col0" class="data row16 col0" >0.187393</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row17" class="row_heading level0 row17" >SO2 max</th>
#                         <td id="T_9f636_row17_col0" class="data row17 col0" >0.078415</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row18" class="row_heading level0 row18" >H2S max</th>
#                         <td id="T_9f636_row18_col0" class="data row18 col0" >0.061318</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row19" class="row_heading level0 row19" >H2S</th>
#                         <td id="T_9f636_row19_col0" class="data row19 col0" >0.059154</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row20" class="row_heading level0 row20" >SO2</th>
#                         <td id="T_9f636_row20_col0" class="data row20 col0" >-0.009011</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row21" class="row_heading level0 row21" >Precipitació</th>
#                         <td id="T_9f636_row21_col0" class="data row21 col0" >-0.068248</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row22" class="row_heading level0 row22" >Precipitació màxima en 1 minut</th>
#                         <td id="T_9f636_row22_col0" class="data row22 col0" >-0.080950</td>
#             </tr>
#             <tr>
#                         <th id="T_9f636_level0_row23" class="row_heading level0 row23

# %% [markdown]
# #### NOTA: As expected, Target is correlated with PM2.5, other pollutants and few meteorological features.

# %%
# Distribution graph between PM2.5 max against other features. 
#It is not considered Alert feature, because is directly related to PM2.5 max, and its binary result won't let us see feature relations clearly.
fig, axes = plt.subplots(nrows=4, ncols=8, figsize=(20, 20))
axes = axes.flat
columnas_numeric = df0.select_dtypes(include=['float64', 'int']).columns
columnas_numeric = columnas_numeric.drop('PM2.5 max')

for i, colum in enumerate(columnas_numeric):
    sns.regplot(
        x           = df0[colum],
        y           = df0['PM2.5 max'],
        color       = "gray",
        marker      = '.',
        scatter_kws = {"alpha":0.4},
        line_kws    = {"color":"r","alpha":0.7},
        ax          = axes[i]
    )
    axes[i].set_title(f"PM2.5 max vs {colum}", fontsize = 7, fontweight = "bold")
    axes[i].ticklabel_format(style='sci', scilimits=(-4,4), axis='both')
    axes[i].tick_params(labelsize = 6)
    axes[i].set_xlabel("")
    axes[i].set_ylabel("")

# Delete empty axes
for i in [8]:
    fig.delaxes(axes[i])
    
fig.tight_layout()
plt.subplots_adjust(top=0.9)
fig.suptitle('Correlation PM2.5 max', fontsize = 10, fontweight = "bold");

# %% [markdown]
# #### NOTA: As expected, the behaviour between 1 feature and max feature is the same, as well as for min, max average meteorological and pollutant features.

# %% [markdown]
# ## 2.4 OUTLIERS

# %%
# Let's check Outliers in our df0 based on KNN method with pyod library.
from pyod.models.knn import KNN
from sklearn import model_selection


#method KNN: parameter contamination is set in 0.18.

clf = KNN(contamination=0.18)
clf.fit(df0)
y_pred = clf.predict(df0)
error = (y_pred).sum()
msg = "%s: %f " % ('KNN',error)
print(msg)
# Out:
# KNN: 477.000000

# %%
#Let's compare how many Alert = 1 values we lose if outliers were removed
print(df0['Alert'].value_counts())
print(df0[y_pred!=1]['Alert'].value_counts())
# Out:
# 0    2191
# 1     872
# Name: Alert, dtype: int64
# 0    1956
# 1     630
# Name: Alert, dtype: int64

# %% [markdown]
# #### NOTA: There are too many outliers, once removed, we lose around 30% Alert data. Despite it is better not to lose data due to not too many, let's see later if they will/will not be removed.

# %% [markdown]
# # 3. Base Model

# %% [markdown]
# #### NOTA: Let's  create a Base Model with a simple Logistic Regression, firstly to compare removing or not outliers.

# %%
# Import sklearn libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, recall_score, accuracy_score, confusion_matrix, precision_score, roc_auc_score, classification_report

# %%
#Let's create 2 metric evaluate functions. 
#A full version to be used at the end, in selection model, tuning and oversampling, and a partial version one for the rest of analysis.
def full_evaluate(y_test, test_predictions):
    f1=f1_score(y_test, test_predictions)
    recall=recall_score(y_test, test_predictions)
    accuracy=accuracy_score(y_test, test_predictions)
    precision=precision_score(y_test, test_predictions)
    roc=roc_auc_score(y_test, test_predictions)
    cm=confusion_matrix(y_test, test_predictions)
    
    return f1, recall, accuracy, precision, roc, cm

# %%
def partial_evaluate(y_test, test_predictions):
    f1=f1_score(y_test, test_predictions)
    accuracy=accuracy_score(y_test, test_predictions)
    
    return f1, accuracy

# %%
#Let's split our dataset in Train and Test
X_train, X_test, y_train, y_test = train_test_split(
                                        df0.drop('Alert', axis = 'columns'),
                                        df0['Alert'],
                                        train_size   = 0.8,
                                        shuffle      = True)

# %%
# For small dataset and 1 feature against the others, it is better to use liblinear solver method.

lr = LogisticRegression(solver='liblinear')
lr.fit(X_train, y_train)
train_predictions = lr.predict(X_train)
test_predictions = lr.predict(X_test)

print("TRAIN:")
print(partial_evaluate(y_train, train_predictions))
print("TEST:")
print(partial_evaluate(y_test, test_predictions))
# Out:
# TRAIN:
# (0.6241721854304635, 0.8146938775510204)
# TEST:
# (0.6486486486486487, 0.8303425774877651)

# %% [markdown]
# #### NOTA:Let's compare Base model with/without outliers the results are below:

# %%
#KNN method
X1_train, X1_test, y1_train, y1_test = train_test_split(
                                        df0[y_pred!=1].drop('Alert', axis = 'columns'),
                                        df0[y_pred!=1]['Alert'],
                                        train_size   = 0.8,
                                        shuffle      = True)

# %%
lr = LogisticRegression(solver='liblinear')

lr.fit(X1_train, y1_train)
train_predictions1 = lr.predict(X1_train)
test_predictions1 = lr.predict(X1_test)

print("TRAIN:")
print(partial_evaluate(y1_train, train_predictions1))
print("TEST:")
print(partial_evaluate(y1_test, test_predictions1))
# Out:
# TRAIN:
# (0.5538847117794486, 0.8278529980657641)
# TEST:
# (0.5794392523364486, 0.8262548262548263)

# %% [markdown]
# #### NOTA: Having seen Outliers impact, clearly best results were got including Outliers.
# #### CONCLUSION: Outliers need to be included.

# %% [markdown]
# # 4. Pre-Processing DATA

# %% [markdown]
# #### NOTA: Let's compare Std. Scaler, Normalized and Rescale. To see what is the better pre-processing method, including outliers.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
#No Pre-processing results got before. [xx]
print("TRAIN:")
print(partial_evaluate(y_train, train_predictions))
print("TEST:")
print(partial_evaluate(y_test, test_predictions))
# Out:
# TRAIN:
# (0.6241721854304635, 0.8146938775510204)
# TEST:
# (0.6486486486486487, 0.8303425774877651)

# %% [markdown]
# ## 4.1 Standardize DATA

# %%
# I will introduce a pipeline to simplify and clean the code

steps = [('scaler', StandardScaler()),('lgr',LogisticRegression(solver='liblinear'))]
pipe_lr = Pipeline(steps)

pipe_lr.fit(X_train, y_train)
train_predictions = pipe_lr.predict(X_train)
test_predictions = pipe_lr.predict(X_test)

print("TRAIN:")
print(partial_evaluate(y_train, train_predictions))
print("TEST:")
print(partial_evaluate(y_test, test_predictions))
# Out:
# TRAIN:
# (0.6373268133659331, 0.8183673469387756)
# TEST:
# (0.6688963210702341, 0.8384991843393148)

# %% [markdown]
# ## 4.2 Rescale DATA

# %%
steps = [('rescale', MinMaxScaler()),('lgr',LogisticRegression(solver='liblinear'))]
pipe_lr = Pipeline(steps)

pipe_lr.fit(X_train, y_train)
train_predictions = pipe_lr.predict(X_train)
test_predictions = pipe_lr.predict(X_test)

print("TRAIN:")
print(partial_evaluate(y_train, train_predictions))
print("TEST:")
print(partial_evaluate(y_test, test_predictions))
# Out:
# TRAIN:
# (0.6226259289843105, 0.813469387755102)
# TEST:
# (0.6460481099656358, 0.831973898858075)

# %% [markdown]
# ## 4.3 Normalize DATA

# %%
steps = [('normalize', Normalizer()),('lgr',LogisticRegression(solver='liblinear'))]
pipe_lr = Pipeline(steps)

pipe_lr.fit(X_train, y_train)
train_predictions = pipe_lr.predict(X_train)
test_predictions = pipe_lr.predict(X_test)

print("TRAIN:")
print(partial_evaluate(y_train, train_predictions))
print("TEST:")
print(partial_evaluate(y_test, test_predictions))
# Out:
# TRAIN:
# (0.13695090439276486, 0.7273469387755102)
# TEST:
# (0.16842105263157894, 0.7422512234910277)

# %% [markdown]
# #### CONCLUSION: Standard Scaler, Rescale and No Pre-processing got similar results, and much better than Normalize. So, I will use Standard Scaler method, because it is convenience to get data standardized and Train and test F1 score got were similar.

# %% [markdown]
# # 5. Feature Importance

# %% [markdown]
# #### NOTA:  In order to simplify the analysis, let's try PCA and Feature importance methods to reduce features dataset. Moreover, it will help us for the FrontEnd in order to introduce as little as possible number of features by user (manual option), but with the highest impact into the model.

# %% [markdown]
# ## 5.1 PCA

# %%
from sklearn.decomposition import PCA
from sklearn.ensemble import ExtraTreesClassifier

#Pre-processed data
scaler=StandardScaler()
scaler.fit(X_train)
X_scaled=scaler.transform(X_train)

#PCA
pca=PCA(n_components=.85) # Min explained variance of 85%
pca.fit(X_scaled) 
X_pca=pca.transform(X_scaled) 

print("shape of X_pca", X_pca.shape)
expl = pca.explained_variance_ratio_
print(expl)
print('suma:',sum(expl[0:33]))

 
#Graph
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()
# Out:
# shape of X_pca (2450, 8)
# [0.31119014 0.1686389  0.11561031 0.07535257 0.06498513 0.05059411
#  0.04884603 0.04031187]
# suma: 0.875529054455916

# %% [markdown]
# #### NOTA: With 8 PCA components, we are able to explain 85% of variance.

# %%
#Let's test base model with 8 components
steps = [('scaler', StandardScaler()),
         ('pca', PCA(n_components=8)),
         ('lgr', LogisticRegression(solver='liblinear'))]
pipe_lr = Pipeline(steps)

pipe_lr.fit(X_train, y_train)
train_predictions = pipe_lr.predict(X_train)
test_predictions = pipe_lr.predict(X_test)

print("TRAIN:")
print(partial_evaluate(y_train, train_predictions))
print("TEST:")
print(partial_evaluate(y_test, test_predictions))
# Out:
# TRAIN:
# (0.625, 0.8138775510204082)
# TEST:
# (0.6416382252559727, 0.8287112561174551)

# %% [markdown]
# #### NOTA: PCA is providing similar results than without, but dataset is simplified to 8 PCA features.

# %% [markdown]
# ## 5.2 Feature importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt

etc = ExtraTreesClassifier(n_estimators=100)

#Pre-processed data
scaler=StandardScaler()
scaler.fit(X_train)
X_scaled=scaler.transform(X_train)

#Model
etc.fit(X_scaled, y_train)

ranked_features=pd.Series(etc.feature_importances_, index=X_train.columns)
ranked_features.nlargest(25).plot(kind='bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Based on correlated heat map and feature importance, let's take features selected: PM2.5, PM10, NO2, Pressió atmosfèrica, Temperatura, Velocitat del vent a 10 m (esc.) and Target Alert feature. I do not consider maximum feature of each one selected, because of higher correlation exists.

# %%
#Let's check columns to copy data correctly
df0.columns
# Out:
# Index(['H2S max', 'NO max', 'NO2 max', 'NOx max', 'PM10 max', 'PM2.5 max',
#        'SO2 max', 'H2S', 'NO', 'NO2', 'NOx', 'PM10', 'PM2.5', 'SO2',
#        'Pressió atmosfèrica màxima', 'Pressió atmosfèrica mínima',
#        'Humitat relativa màxima', 'Velocitat del vent a 10 m (esc.)',
#        'Direcció de vent 10 m (m. 1)', 'Temperatura', 'Humitat relativa',
#        'Pressió atmosfèrica', 'Precipitació', 'Irradiància solar global',
#        'Temperatura màxima', 'Temperatura mínima', 'Humitat relativa mínima',
#        'Ratxa màxima del vent a 10 m',
#        'Direcció de la ratxa màxima del vent a 10 m',
#        'Precipitació màxima en 1 minut', 'Alert'],
#       dtype='object')

# %%
df1 = df0[['PM2.5','PM10','NO2','Pressió atmosfèrica','Temperatura','Velocitat del vent a 10 m (esc.)','Alert']]
df1.head()
# Out:
#        PM2.5       PM10        NO2  Pressió atmosfèrica  Temperatura  \
# 0  14.666667  26.555556  17.900000          1017.787500     2.714583
# 1   9.125000  19.666667  12.666667          1023.345833     4.029167
# 2  11.541667  15.291667  22.416667          1022.672917     3.562500
# 3   7.458333  13.333333  20.800000          1020.043750     7.995833
# 4   5.041667  17.541667  13.521739          1016.004167     8.281250
#
#    Velocitat del vent a 10 m (esc.)  Alert
# 0                          5.052083      0
# 1                          4.885417      0
# 2                          2.631250      0
# 3                          3.593750      0
# 4                          5.885417      0

# %%
#Let's save definitive dataframe in csv to be used if needed later
df1.to_csv(r'FrontEnd_docs_related/Dataframe.csv')

# %%
#Let's simplify dataset features 
X_train, X_test, y_train, y_test = train_test_split(
                                        df1.drop('Alert', axis = 'columns'),
                                        df1['Alert'],
                                        train_size   = 0.8,
                                        shuffle      = True)

# %%
steps = [('scaler', StandardScaler()),
         ('lgr', LogisticRegression(solver='liblinear'))]
pipe_lr = Pipeline(steps)

pipe_lr.fit(X_train, y_train)
train_predictions = pipe_lr.predict(X_train)
test_predictions = pipe_lr.predict(X_test)

print("TRAIN:")
print(partial_evaluate(y_train, train_predictions))
print("TEST:")
print(partial_evaluate(y_test, test_predictions))
# Out:
# TRAIN:
# (0.612736660929432, 0.8163265306122449)
# TEST:
# (0.6686746987951807, 0.8205546492659054)

# %% [markdown]
# #### CONCLUSION: PCA and Features selected got similar results, so let's use Feature Importance because later on, it will help us to introduce features in frontend. Moreover, train and test results F1 score and accuracy are the same. Additionally, we will consider Standard Scaler as pre-processing.

# %% [markdown]
# # 6. Modelling

# %% [markdown]
# ## 6.1 Model comparison

# %%
#Let's use dataset splitted box [88]

# %%
import warnings
warnings.filterwarnings(action='ignore', category=UserWarning)

# %%
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# Compare Algorithms
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import RandomOverSampler
from xgboost import XGBClassifier


# prepare configuration for cross validation test harness
seed = 7

# models: as unbalanced dataset we have, let's use parameter class_weight balanced if it applies
models = []
models.append(('LR', LogisticRegression(max_iter=100,solver='liblinear', class_weight='balanced')))
models.append(('KNC', KNeighborsClassifier()))
models.append(('DTC', DecisionTreeClassifier(class_weight='balanced')))
models.append(('SVC', SVC(class_weight='balanced')))
models.append(('RFC', RandomForestClassifier(class_weight='balanced')))
models.append(('XGB', XGBClassifier(eval_metric='mlogloss',use_label_encoder =False,scale_pos_weight = float)))

#Pre-processed data
scaler=StandardScaler()
scaler.fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# evaluate each model in turn
results = []
names = []
for name, model in models:
    rkf = model_selection.RepeatedKFold(n_splits=10)
    #f1_score is used because of unbalanced dataset available. Accuracy score won't be suitable.
    cv_results = model_selection.cross_val_score(model, X_train_scaled, y_train, cv=rkf,scoring='f1')  
    results.append(cv_results)
    names.append(name)
    msg1 = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg1)
    model.fit(X_train_scaled, y_train)
    train_predictions_model = model.predict(X_train_scaled)
    test_predictions = model.predict(X_test_scaled)
    print(full_evaluate(y_test, test_predictions))


# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# LR: 0.650106 (0.038147)
# (0.7167070217917675, 0.7872340425531915, 0.8091353996737357, 0.6577777777777778, 0.8030287859824781, array([[348,  77],
#        [ 40, 148]]))
# KNC: 0.612867 (0.049497)
# (0.6438746438746439, 0.601063829787234, 0.7960848287112561, 0.6932515337423313, 0.7417083854818523, array([[375,  50],
#        [ 75, 113]]))
# DTC: 0.528347 (0.051203)
# (0.5205479452054795, 0.5053191489361702, 0.7145187601957586, 0.536723163841808, 0.656188986232791, array([[343,  82],
#        [ 93,  95]]))
# SVC: 0.661522 (0.035234)
# (0.7163461538461539, 0.7925531914893617, 0.8075040783034257, 0.6535087719298246, 0.8033354192740925, array([[346,  79],
#        [ 39, 149]]))
# RFC: 0.604852 (0.046233)
# (0.6030769230769232, 0.5212765957446809, 0.7895595432300163, 0.7153284671532847, 0.714755944931164, array([[386,  39],
#        [ 90,  98]]))
# XGB: 0.594252 (0.048542)
# (0.6094674556213017, 0.5478723404255319, 0.7846655791190864, 0.6866666666666666, 0.7186420525657071, array([[378,  47],
#        [ 85, 103]]))

# %% [markdown]
# #### CONCLUSION: SVC model slightly better Classification metrics values than LR and the rest. As we want to get an Alert System focused on minimizing False Negatives, as preventive and safety system desired, F1, Recall and Confusion matrix are the main importance metrics for us.

# %% [markdown]
# ## 6.2 Hypertunning SVC

# %%
#Let's import GridSearch library to introduce parameters to tun
from sklearn.model_selection import GridSearchCV

# defining parameter range
param_grid = {'C':[0.1,1,10,100],'gamma': [1,0.1,0.01,'scale'], 'kernel':['rbf','linear']}

svc = SVC(class_weight='balanced')


grid = GridSearchCV(
        estimator  = svc,
        param_grid = param_grid,
        scoring    = 'f1')

# fitting the model for grid search
grid.fit(X_train_scaled, y_train)


# Results

print(grid.best_estimator_)

grid_predictions = grid.predict(X_test_scaled)

full_evaluate(y_test, grid_predictions)
# Out:
# SVC(C=1, class_weight='balanced')
# (0.7163461538461539,
#  0.7925531914893617,
#  0.8075040783034257,
#  0.6535087719298246,
#  0.8033354192740925,
#  array([[346,  79],
#         [ 39, 149]]))

# %% [markdown]
# #### CONCLUSION: SVC model with hyperparameters C=1, gamma=scale, kernel=rbf and class_weihgt balanced got same results without tuning. The reason behind that could be default parameters used in model selection, where the same parameters tuned.
# #### As last chance to improve, let's see if Oversampling can improve results.

# %% [markdown]
# ## 6.3 Oversampling methods

# %%
#Without oversampling

steps = [('scaler', StandardScaler()),
         ('SVC', SVC(class_weight='balanced'))]

pipe_svc = Pipeline(steps)

pipe_svc.fit(X_train, y_train)
test_predictions_svc = pipe_svc.predict(X_test)

full_evaluate(y_test, test_predictions_svc)
# Out:
# (0.7163461538461539,
#  0.7925531914893617,
#  0.8075040783034257,
#  0.6535087719298246,
#  0.8033354192740925,
#  array([[346,  79],
#         [ 39, 149]]))

# %% [markdown]
# ### 6.3.1 SMOTE

# %%
from imblearn.combine import SMOTETomek

os_us = SMOTETomek(sampling_strategy='not majority')
X_train_res, y_train_res = os_us.fit_resample(X_train, y_train)

# %%
pipe_svc.fit(X_train_res, y_train_res)
train_predictions_svc = pipe_svc.predict(X_train_res)
test_predictions_svc = pipe_svc.predict(X_test)

full_evaluate(y_test, test_predictions_svc)
# Out:
# (0.7070217917675545,
#  0.776595744680851,
#  0.802610114192496,
#  0.6488888888888888,
#  0.7953566958698373,
#  array([[346,  79],
#         [ 42, 146]]))

# %% [markdown]
# ### 6.3.2 OVERSAMPLING

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='minority')
X_train_ove, y_train_ove = oversample.fit_resample(X_train, y_train)

# %%
pipe_svc.fit(X_train_ove, y_train_ove)
train_predictions_svc = pipe_svc.predict(X_train_ove)
test_predictions_svc = pipe_svc.predict(X_test)

full_evaluate(y_test, test_predictions_svc)
# Out:
# (0.7177033492822966,
#  0.7978723404255319,
#  0.8075040783034257,
#  0.6521739130434783,
#  0.8048185231539424,
#  array([[345,  80],
#         [ 38, 150]]))

# %% [markdown]
# ### 6.3.3 UNDERSAMPLING

# %%
from imblearn.under_sampling import RandomUnderSampler
undersample = RandomUnderSampler(sampling_strategy='majority')
X_train_und, y_train_und = undersample.fit_resample(X_train, y_train)

# %%
pipe_svc.fit(X_train_und, y_train_und)
train_predictions_svc = pipe_svc.predict(X_train_und)
test_predictions_svc = pipe_svc.predict(X_test)

full_evaluate(y_test, test_predictions_svc)
# Out:
# (0.7153284671532847,
#  0.7819148936170213,
#  0.8091353996737357,
#  0.6591928251121076,
#  0.8015456821026283,
#  array([[349,  76],
#         [ 41, 147]]))

# %% [markdown]
# #### CONCLUSION: All 3 methods got similar results, but I considered Oversampling method because it got slightly better metrics results and confusion matrix with less False Negative result.

# %% [markdown]
# # 7. Summary and Results

# %% [markdown]
# As overall conclusion, our best results were got by:
#     - Simplifying dataset to 7 features
#     - SVC method (parameters tuned)
#     - Class_weight balanced
#     - Standardized data
#     - Oversampling method

# %%
steps = [('scaler', StandardScaler()),
         ('SVC', SVC(class_weight='balanced'))]

pipe_svc = Pipeline(steps)

pipe_svc.fit(X_train_ove, y_train_ove)
train_predictions_svc = pipe_svc.predict(X_train_und)
test_predictions_svc = pipe_svc.predict(X_test)


full_evaluate(y_test, test_predictions_svc)
# Out:
# (0.7177033492822966,
#  0.7978723404255319,
#  0.8075040783034257,
#  0.6521739130434783,
#  0.8048185231539424,
#  array([[345,  80],
#         [ 38, 150]]))

# %% [markdown]
# # 8. Saving model

# %%
import pickle

# %%
#Let's save the model into FrontEnd folder
pickle_out = open("FrontEnd_docs_related/aplication.pkl", "wb") 
pickle.dump(pipe_svc, pickle_out) 
pickle_out.close()
