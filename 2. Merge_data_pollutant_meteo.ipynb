# %% [markdown]
# ## In this Notebook, I will merge and structure Pollutant and Meteorological datasets, in order to get ready for being used as definitive dataset to be modelled under Machine Learning

# %% [markdown]
# # 1. Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 2. Import Pollutant dataset

# %%
df1 = pd.read_csv("Data_sets/Pollutant_ready.csv", index_col=0)
pd.options.display.max_columns = None
df1
# Out:
#             data  CO max  H2S max  NO max  NO2 max  NOx max  PM1 max  \
# 0     2010-01-01     0.2      1.4     1.0      7.0      NaN      NaN
# 1     2010-01-02     0.2      1.8    13.0     44.0      NaN      NaN
# 2     2010-01-03     0.3      1.6    17.0     48.0      NaN      NaN
# 3     2010-01-04     0.2      2.0    26.0     42.0      NaN      NaN
# 4     2010-01-05     0.4      1.4    23.0     44.0      NaN      NaN
# ...          ...     ...      ...     ...      ...      ...      ...
# 3987  2020-12-27     NaN      3.1    13.0     44.0     63.0     23.0
# 3988  2020-12-28     NaN      1.6     6.0     27.0     37.0      4.0
# 3989  2020-12-29     NaN      1.5     5.0     15.0     16.0      8.0
# 3990  2020-12-30     NaN      1.3     3.0     20.0     25.0      2.0
# 3991  2020-12-31     NaN      1.5     7.0     40.0     51.0     21.0
#
#       PM10 max  PM2.5 max  SO2 max        CO       H2S        NO        NO2  \
# ...

# %% [markdown]
# # 3. Import Meteorological dataset

# %%
df2 = pd.read_csv("Data_sets/Meteo_ready.csv", index_col=0)
pd.options.display.max_columns = None
df2
# Out:
#      data_lectura  Pressió atmosfèrica màxima  Pressió atmosfèrica mínima  \
# 0      2010-01-01                 1003.531915                 1002.680851
# 1      2010-01-02                 1016.875000                 1016.312500
# 2      2010-01-03                 1016.458333                 1016.125000
# 3      2010-01-04                 1008.625000                 1008.354167
# 4      2010-01-05                 1000.083333                  999.833333
# ...           ...                         ...                         ...
# 4010   2020-12-27                 1009.404167                 1008.766667
# 4011   2020-12-28                  995.566667                  994.956250
# 4012   2020-12-29                 1001.879167                 1001.518750
# 4013   2020-12-30                 1010.639583                 1010.081250
# 4014   2020-12-31                 1011.370833                 1011.060417
#
#       Humitat relativa màxima  Velocitat del vent a 10 m (esc.)  \
# ...

# %% [markdown]
# # 4. Merge Pollutant and Meteorological datasets

# %%
#As pollutant dataset has fewer rows than meteorological one, then, datasets are merged with pollutant primary domain data 
merged = pd.merge(left=df1, right=df2, how='left', left_on='data', right_on='data_lectura')
merged
# Out:
#             data  CO max  H2S max  NO max  NO2 max  NOx max  PM1 max  \
# 0     2010-01-01     0.2      1.4     1.0      7.0      NaN      NaN
# 1     2010-01-02     0.2      1.8    13.0     44.0      NaN      NaN
# 2     2010-01-03     0.3      1.6    17.0     48.0      NaN      NaN
# 3     2010-01-04     0.2      2.0    26.0     42.0      NaN      NaN
# 4     2010-01-05     0.4      1.4    23.0     44.0      NaN      NaN
# ...          ...     ...      ...     ...      ...      ...      ...
# 3987  2020-12-27     NaN      3.1    13.0     44.0     63.0     23.0
# 3988  2020-12-28     NaN      1.6     6.0     27.0     37.0      4.0
# 3989  2020-12-29     NaN      1.5     5.0     15.0     16.0      8.0
# 3990  2020-12-30     NaN      1.3     3.0     20.0     25.0      2.0
# 3991  2020-12-31     NaN      1.5     7.0     40.0     51.0     21.0
#
#       PM10 max  PM2.5 max  SO2 max        CO       H2S        NO        NO2  \
# ...

# %%
#Let's check type features
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3992 entries, 0 to 3991
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   data                                         3992 non-null   object
#  1   CO max                                       343 non-null    float64
#  2   H2S max                                      3961 non-null   float64
#  3   NO max                                       3952 non-null   float64
#  4   NO2 max                                      3952 non-null   float64
#  5   NOx max                                      3323 non-null   float64
#  6   PM1 max                                      2638 non-null   float64
#  7   PM10 max                                     3073 non-null   float64
#  8   PM2.5 max                                    3066 non-null   float64
# ...

# %% [markdown]
# # 5. Export Dataset merged

# %%
#dataset merged as csv file
merged.to_csv(r'Data_sets/Pollutant_Meteo_merged_ready.csv')
